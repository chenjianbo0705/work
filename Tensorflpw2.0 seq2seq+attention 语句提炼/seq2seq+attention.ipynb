# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import activations
from tensorflow.keras.layers import Layer, Input, Embedding, LSTM, Dense, Attention
from tensorflow.keras.models import Model

# %%
reviews = pd.read_csv("Reviews.csv")

# %%
reviews.shape
# Out:
# (568454, 10)

# %%
reviews.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
reviews.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
# Remove null values and unneeded features
reviews = reviews.dropna()
reviews = reviews.drop(['Id','ProductId','UserId','ProfileName','HelpfulnessNumerator','HelpfulnessDenominator','Score','Time'],1)
reviews = reviews.reset_index(drop=True)

# %%
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are"
}

# %%
def clean_text(text, remove_stopwords = True):
    
    # Convert words to lower case
    text = text.lower()
    
    # Replace contractions with their longer forms 
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
    
    # Format words and remove unwanted characters
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    
    # Optionally, remove stop words
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text

# %%
# Clean the summaries and texts
clean_summaries = []
for summary in reviews.Summary[0:5000]:
    clean_summaries.append(clean_text(summary))
print("Summaries are complete.")

clean_texts = []
for text in reviews.Text[0:5000]:
    clean_texts.append(clean_text(text))
print("Texts are complete.")
# Out:
# Summaries are complete.
# Texts are complete.

# %%
# Inspect the cleaned summaries and texts to ensure they have been cleaned well
for i in range(5):
    print("Clean Review #",i+1)
    print(clean_summaries[i])
    print(clean_texts[i])
    print()
# Out:
# Clean Review # 1
# good quality dog food
# bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
#
# Clean Review # 2
# advertised
# product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
#
# Clean Review # 3
# delight says
# confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story c lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
#
# Clean Review # 4
# cough medicine
# looking secret ingredient robitussin believe found got addition root beer extract ordered good made cherry soda flavor medicinal
#
# Clean Review # 5
# great taffy
# great taffy great price wide assortment yummy taffy delivery quick taffy lover deal

# %%
vocab_words = []
def count_words( text):
    for sentence in text:
        for word in sentence.split():
            if word not in vocab_words:
                vocab_words.append(word)

# %%
count_words(clean_summaries)
count_words(clean_texts)

# %%
vocab_words
# Out:
# ['good',
#  'quality',
#  'dog',
#  'food',
#  'advertised',
#  'delight',
#  'says',
#  'cough',
#  'medicine',
#  'great',
#  'taffy',
#  'nice',
#  'expensive',
#  'brands',
#  'wonderful',
#  'tasty',
#  'yay',
#  'barley',
#  'healthy',
#  'best',
#  'hot',
#  'sauce',
#  'world',
#  'cats',
#  'love',
#  'diet',
#  'better',
#  'regular',
#  'fans',
#  'new',
#  'fresh',
#  'greasy',
#  'strawberry',
#  'twizzlers',
#  'yummy',
#  'lots',
#  'expect',
#  'poor',
#  'taste',
#  'sweet',
#  'candy',
#  'home',
#  'delivered',
#  'twizlers',
#  'always',
#  'delicious',
#  'product',
#  'please',
#  'sell',
#  'mexico',
#  'nasty',
#  'flavor',
#  'bargain',
#  'price',
#  'machine',
#  'instant',
#  'oatmeals',
#  'irish',
#  'oatmeal',
#  'hurry',
#  'satisfying',
#  'gluten',
#  'free',
#  'way',
#  'start',
#  'day',
#  'wife',
#  'favorite',
#  'breakfast',
#  'would',
#  'buy',
#  'mcanns',
#  'tastes',
#  'lovers',
#  'convenience',
#  'hearty',
#  'mushy',
#  'next',
#  'time',
#  'order',
#  'variety',
#  'pack',
#  'stuff',
#  'like',
#  'came',
#  'back',
#  'go',
#  'nuts',
#  'ass',
#  'kickin',
#  'peanuts',
#  'roasts',
#  'smooth',
#  'brew',
#  'guests',
#  'awesome',
#  'deal',
#  'wrong',
#  'awsome',
#  'kids',
#  'neighborhood',
#  'loved',
#  'us',
#  'target',
#  'pretty',
#  'stale',
#  'hammer',
#  'nutrition',
#  'fizz',
#  'rocks',
#  'source',
#  'electrolytes',
#  'preventing',
#  'cramps',
#  'low',
#  'carb',
#  'alternative',
#  'gatorade',
#  'much',
#  'pay',
#  'bag',
#  'chocolate',
#  'pretzels',
#  'pretzel',
#  'haven',
#  'gummi',
#  'bigger',
#  'ever',
#  'latice',
#  'tart',
#  'warning',
#  'alcohol',
#  'sugars',
#  'nothing',
#  'special',
#  'tea',
#  'cold',
#  'weather',
#  'forget',
#  'molecular',
#  'gastronomy',
#  'rockes',
#  'coffee',
#  'creamer',
#  'natural',
#  'balance',
#  'lamb',
#  'rice',
#  'increased',
#  'dogs',
#  'itching',
#  'allergies',
#  'stomach',
#  'problems',
#  'life',
#  'sensitive',
#  'mmmmm',
#  'convenient',
#  'allergy',
#  'perfect',
#  'english',
#  'bulldog',
#  'bad',
#  'wise',
#  '6',
#  'star',
#  'item',
#  'support',
#  'omaha',
#  'apple',
#  'tartlets',
#  'disappointing',
#  'wasting',
#  'vinegar',
#  'cucumber',
#  'shame',
#  'asparagus',
#  'bliss',
#  'idea',
#  'angel',
#  'puffs',
#  'every',
#  'green',
#  'freah',
#  'bright',
#  'clean',
#  'review',
#  'cookies',
#  'everyday',
#  'cookie',
#  'far',
#  'cat',
#  'older',
#  'feline',
#  'uti',
#  'palatable',
#  'allergic',
#  'kitties',
#  'holistic',
#  'select',
#  'spicy',
#  'ramen',
#  'burns',
#  'amazing',
#  'last',
#  'bite',
#  'value',
#  'cheaper',
#  'locally',
#  'looks',
#  'beautiful',
#  'happy',
#  'face',
#  'simply',
#  'excellent',
#  'saver',
#  'snack',
#  'licorice',
#  'sized',
#  'kick',
#  'broken',
#  'bottle',
#  'bottoms',
#  'salsa',
#  'ehhh',
#  'cornmeal',
#  'marinade',
#  'rip',
#  'jell',
#  'o',
#  'tasting',
#  'sea',
#  'salt',
#  'iodine',
#  'simple',
#  'greatest',
#  'right',
#  'size',
#  'tasteless',
#  'calorie',
#  'sooooo',
#  'banana',
#  'runts',
#  'heads',
#  'worked',
#  'ricore',
#  'forever',
#  'fluffy',
#  'soft',
#  'sugary',
#  'teen',
#  'lemon',
#  'juice',
#  'handy',
#  'realemon',
#  'amazon',
#  'relaxing',
#  'almost',
#  'something',
#  'smoke',
#  'never',
#  'paid',
#  'marley',
#  'mellow',
#  'mood',
#  'lite',
#  'half',
#  'lemonade',
#  'help',
#  'sleep',
#  'chip',
#  'garbonzo',
#  'bean',
#  'flour',
#  'yum',
#  'falafel',
#  'make',
#  'fruit',
#  'light',
#  'miracle',
#  'ok',
#  'health',
#  'benefits',
#  'arrived',
#  '2',
#  'days',
#  'lunch',
#  'little',
#  'mints',
#  'pricey',
#  'altoids',
#  'mini',
#  'tins',
#  'smalls',
#  'wintergreen',
#  'sugarfree',
#  'reusable',
#  'containers',
#  'huge',
#  'hit',
#  'office',
#  'em',
#  'breath',
#  'average',
#  'loves',
#  'fat',
#  'senior',
#  'citizens',
#  'nearly',
#  'killed',
#  'changed',
#  'formula',
#  'makes',
#  'sick',
#  'case',
#  'looking',
#  'different',
#  'cannot',
#  'correct',
#  'mccormick',
#  'brand',
#  'ahmad',
#  'loose',
#  'imperial',
#  'blend',
#  'fragrant',
#  'real',
#  'bloody',
#  'mary',
#  'mixer',
#  'mcclures',
#  'mix',
#  'really',
#  'give',
#  'watermelon',
#  'citron',
#  'furniture',
#  'polish',
#  'big',
#  'tub',
#  'neutral',
#  'quantity',
#  'deceitful',
#  'eukanuba',
#  'puppy',
#  'small',
#  'breed',
#  'high',
#  'gave',
#  'wicked',
#  'gas',
#  'omg',
#  'jelly',
#  'belly',
#  'anytime',
#  'cup',
#  'get',
#  'store',
#  'disappointed',
#  'kcups',
#  'keeps',
#  'dentest',
#  'chair',
#  'super',
#  'superfoods',
#  'easy',
#  'pok',
#  'chops',
#  'sad',
#  'outcome',
#  'energy',
#  'shot',
#  'waste',
#  'money',
#  'handle',
#  'caffeine',
#  'yummier',
#  'reeks',
#  'chemicals',
#  'lifestyle',
#  'sugar',
#  'raw',
#  'manufacturing',
#  'diminish',
#  'terrible',
#  'agricultural',
#  'practices',
#  'lie',
#  'use',
#  'white',
#  'thanks',
#  'scott',
#  'weak',
#  'packaging',
#  'g',
#  'f',
#  'chips',
#  'priced',
#  'lack',
#  'rotel',
#  'saves',
#  'daily',
#  'basis',
#  'fabulous',
#  'mild',
#  'enough',
#  'lol',
#  'sure',
#  'organic',
#  'fantastic',
#  'guayaki',
#  'provides',
#  'rocket',
#  'works',
#  'boost',
#  'tasted',
#  'tested',
#  'trucker',
#  'drink',
#  'without',
#  'artificial',
#  'ingredients',
#  'getting',
#  'awful',
#  'barely',
#  'describe',
#  'could',
#  'vanilla',
#  'tootsie',
#  'rolls',
#  'one',
#  'favoritte',
#  'foods',
#  'wow',
#  'dissapointed',
#  'swiss',
#  'chalet',
#  'oyster',
#  'absolutely',
#  'gag',
#  'gift',
#  'fast',
#  'penguin',
#  'pooper',
#  'mate',
#  'hazelnut',
#  'creamers',
#  'shipped',
#  'work',
#  'pop',
#  'tarts',
#  'art',
#  'yes',
#  'king',
#  'seasoning',
#  'salts',
#  'toasted',
#  'sesame',
#  'oil',
#  'eating',
#  'whole',
#  'veggie',
#  'brush',
#  'ice',
#  'teething',
#  'difficult',
#  'impressed',
#  'feeder',
#  'beans',
#  'exactly',
#  'expected',
#  'line',
#  'swedish',
#  'pearl',
#  'belgian',
#  'wine',
#  'maker',
#  'olive',
#  'weavers',
#  'fan',
#  'treat',
#  'bitter',
#  'drinking',
#  'latin',
#  'america',
#  'aroma',
#  'bar',
#  'find',
#  'anywhere',
#  'else',
#  'granola',
#  'another',
#  'husband',
#  'surprise',
#  'highly',
#  'recommended',
#  'saving',
#  'grace',
#  'mountain',
#  'nantucket',
#  'k',
#  'cups',
#  'chicken',
#  'noodle',
#  'soup',
#  'since',
#  'slice',
#  'bread',
#  'deliciously',
#  'scrumptious',
#  'heinz',
#  'porcini',
#  'mushrooms',
#  'mostly',
#  'large',
#  'pieces',
#  'highest',
#  'valentine',
#  'winner',
#  'near',
#  'wild',
#  'chick',
#  'brown',
#  'ham',
#  'base',
#  'msg',
#  'delisious',
#  'pancakes',
#  'around',
#  'egg',
#  'arrowhead',
#  'mills',
#  'grain',
#  'buttermilk',
#  'shipping',
#  'soothing',
#  'minty',
#  'take',
#  'seconds',
#  'read',
#  'french',
#  'roast',
#  'n',
#  'bags',
#  'franch',
#  'double',
#  'pleasure',
#  'single',
#  'guy',
#  'acquired',
#  'look',
#  'elsewhere',
#  'grains',
#  'hey',
#  'famous',
#  'reason',
#  'god',
#  'hard',
#  'kettle',
#  'potato',
#  'fully',
#  'loaded',
#  'baked',
#  'lightly',
#  'spiced',
#  'crunchy',
#  'glad',
#  '1',
#  'oz',
#  'slight',
#  'jalapeno',
#  'onion',
#  'ridiculously',
#  'pucker',
#  'thick',
#  'quite',
#  'salty',
#  'vinegary',
#  'dairy',
#  'unique',
#  'thai',
#  'honey',
#  'dijon',
#  'leaves',
#  'aftertaste',
#  'ny',
#  'cheddar',
#  'yowzah',
#  'tangy',
#  'goodness',
#  'heavy',
#  'crisp',
#  'bbq',
#  'cost',
#  'barbeque',
#  'perfection',
#  'flavored',
#  'supreme',
#  'oooh',
#  'want',
#  'gaain',
#  'twenty',
#  'pounds',
#  'control',
#  'whatsoever',
#  'flavors',
#  'addicitive',
#  'become',
#  'chippoisseur',
#  'finally',
#  'superbowl',
#  'scooores',
#  'knees',
#  'cheese',
#  'sour',
#  'cream',
#  'box',
#  'beat',
#  'resist',
#  'spice',
#  'lover',
#  'addictive',
#  'crunchiness',
#  'moisture',
#  '70',
#  'cooked',
#  'used',
#  'firm',
#  'creamy',
#  'chivey',
#  'prefer',
#  'habit',
#  'forming',
#  'even',
#  'already',
#  'oh',
#  'indulgence',
#  'unsalted',
#  'yet',
#  'companions',
#  'wont',
#  'touch',
#  'maybe',
#  'worst',
#  'boulder',
#  'malt',
#  'salted',
#  'heavily',
#  'first',
#  'tongue',
#  'puckering',
#  'tang',
#  'crunch',
#  'period',
#  'extra',
#  'snob',
#  'alert',
#  'gourmet',
#  'powerful',
#  'horrible',
#  'miss',
#  'burnt',
#  'gaaak',
#  'extreme',
#  'absotively',
#  'posilutely',
#  'gone',
#  'hill',
#  'completely',
#  'ripped',
#  'c',
#  'h',
#  'p',
#  'r',
#  'y',
#  'b',
#  'd',
#  'e',
#  'u',
#  'beware',
#  'buying',
#  'rancid',
#  'tiniest',
#  'bit',
#  'disgusting',
#  'strong',
#  'fried',
#  'dripping',
#  'added',
#  'garbage',
#  'madhouse',
#  'munchies',
#  'sold',
#  'damaged',
#  'holes',
#  'stains',
#  'mouse',
#  'orgasmic',
#  'packs',
#  'punch',
#  'cant',
#  'believe',
#  'york',
#  'farts',
#  'smell',
#  'onions',
#  'thing',
#  'addicted',
#  'happened',
#  'recipe',
#  'yoli',
#  'skin',
#  'lips',
#  'sodium',
#  'smiles',
#  'service',
#  'decently',
#  'close',
#  'expiration',
#  'date',
#  'eat',
#  'years',
#  'defacto',
#  'standard',
#  'caution',
#  'kiss',
#  'tummy',
#  'dont',
#  'know',
#  'expired',
#  'stock',
#  'sometimes',
#  '4',
#  'stars',
#  'crispy',
#  'robust',
#  'smaller',
#  'things',
#  'need',
#  'made',
#  'mistake',
#  'vickie',
#  'well',
#  'balanced',
#  'earl',
#  'grey',
#  'success',
#  'shrimp',
#  'stir',
#  'fry',
#  'true',
#  'bavarian',
#  'creme',
#  'oldest',
#  'still',
#  'michigan',
#  '1866',
#  'caramel',
#  'baking',
#  'toppings',
#  'tips',
#  'using',
#  'agave',
#  'weigh',
#  '46',
#  'fluid',
#  'ounces',
#  'sweetner',
#  'syrup',
#  'substitute',
#  'container',
#  'sweetener',
#  'replacing',
#  'nectar',
#  'found',
#  'needs',
#  'ask',
#  'widely',
#  'available',
#  'plocky',
#  'smokey',
#  'chipotle',
#  'tortill',
#  'faboo',
#  'dangerous',
#  'prone',
#  'binges',
#  'grow',
#  'tortilla',
#  'eaten',
#  'got',
#  'country',
#  'instead',
#  'chili',
#  'three',
#  'gum',
#  'stop',
#  'carrying',
#  'om',
#  'nom',
#  'schrumshist',
#  'music',
#  'palate',
#  'kept',
#  'secret',
#  'additive',
#  'fanfreakintastic',
#  'smokin',
#  'red',
#  'meh',
#  'label',
#  'misleading',
#  'kind',
#  'bland',
#  'black',
#  'timely',
#  'delivery',
#  'cute',
#  'surprising',
#  'unparalleled',
#  'side',
#  'perhaps',
#  'batch',
#  'drain',
#  'disappointment',
#  'frosting',
#  'cherrybrook',
#  'kitchen',
#  'dum',
#  'dums',
#  'pops',
#  'fridge',
#  'meat',
#  'anti',
#  'oxidant',
#  'smoothie',
#  'perversion',
#  'annie',
#  'homegrown',
#  'wheat',
#  'shells',
#  'macaroni',
#  'gods',
#  'cuttiest',
#  'century',
#  'city',
#  'steam',
#  'soy',
#  'mainly',
#  'gets',
#  'vote',
#  'though',
#  'kikkoman',
#  'anything',
#  'supermarket',
#  'outstanding',
#  'non',
#  'gmo',
#  'amazingly',
#  'laxative',
#  'joe',
#  'tassimo',
#  'discs',
#  'note',
#  'rating',
#  'seller',
#  'kona',
#  'wafers',
#  'tao',
#  'sampler',
#  'milka',
#  'dad',
#  'liked',
#  'family',
#  'kleri',
#  'cranberries',
#  'ferret',
#  'treats',
#  'edible',
#  'speedy',
#  'sons',
#  '9',
#  '11',
#  'making',
#  'adult',
#  'supervision',
#  'age',
#  'neat',
#  'project',
#  'spongetastic',
#  'twice',
#  'rudolph',
#  'gingerbread',
#  'house',
#  'fun',
#  'paint',
#  'horrid',
#  'buds',
#  'none',
#  'greater',
#  'heaven',
#  'heavenly',
#  'action',
#  'choclate',
#  'serious',
#  '10',
#  'bucks',
#  'overpriced',
#  'gold',
#  '15',
#  'seems',
#  'quick',
#  'arrival',
#  'basket',
#  'adorable',
#  'presentation',
#  'specialty',
#  'party',
#  'liquor',
#  'scottie',
#  'odd',
#  'fake',
#  'sugarless',
#  'stronger',
#  'bubble',
#  'blowing',
#  'gums',
#  'imo',
#  'helps',
#  'weight',
#  'loss',
#  'royal',
#  'canin',
#  'cocker',
#  'cockers',
#  'buster',
#  'human',
#  'rave',
#  'rolled',
#  'oats',
#  'uk',
#  'india',
#  'version',
#  'countries',
#  'cadbury',
#  'mediocre',
#  'cheap',
#  'consistently',
#  'flavorful',
#  'purist',
#  'addict',
#  'fine',
#  'full',
#  'lea',
#  'caramels',
#  'traditional',
#  'soda',
#  'aluminum',
#  'bomb',
#  'interesting',
#  'info',
#  'second',
#  'mm',
#  'funny',
#  'pocky',
#  'sticks',
#  'melt',
#  'japanese',
#  'popping',
#  'dipped',
#  'manga',
#  'local',
#  'wait',
#  'till',
#  'fall',
#  'together',
#  'wanted',
#  'berry',
#  'ones',
#  'lowered',
#  'overall',
#  'child',
#  'wary',
#  'recomended',
#  'bars',
#  'diets',
#  'vile',
#  'strictly',
#  'break',
#  'easily',
#  'twins',
#  'subscription',
#  'fair',
#  'dessert',
#  'nutritional',
#  'repeated',
#  'deliveries',
#  'jars',
#  'runny',
#  '12',
#  ...]

# %%
special_words = ["<PAD>", "<UNK>", "<GO>", "<EOS>"]
vocab_words = special_words + vocab_words
vocab2id = {word: i for i, word in enumerate(vocab_words)}
id2vocab = {i: word for i, word in enumerate(vocab_words)}

# %%
vocab2id
# Out:
# {'<PAD>': 0,
#  '<UNK>': 1,
#  '<GO>': 2,
#  '<EOS>': 3,
#  'good': 4,
#  'quality': 5,
#  'dog': 6,
#  'food': 7,
#  'advertised': 8,
#  'delight': 9,
#  'says': 10,
#  'cough': 11,
#  'medicine': 12,
#  'great': 13,
#  'taffy': 14,
#  'nice': 15,
#  'expensive': 16,
#  'brands': 17,
#  'wonderful': 18,
#  'tasty': 19,
#  'yay': 20,
#  'barley': 21,
#  'healthy': 22,
#  'best': 23,
#  'hot': 24,
#  'sauce': 25,
#  'world': 26,
#  'cats': 27,
#  'love': 28,
#  'diet': 29,
#  'better': 30,
#  'regular': 31,
#  'fans': 32,
#  'new': 33,
#  'fresh': 34,
#  'greasy': 35,
#  'strawberry': 36,
#  'twizzlers': 37,
#  'yummy': 38,
#  'lots': 39,
#  'expect': 40,
#  'poor': 41,
#  'taste': 42,
#  'sweet': 43,
#  'candy': 44,
#  'home': 45,
#  'delivered': 46,
#  'twizlers': 47,
#  'always': 48,
#  'delicious': 49,
#  'product': 50,
#  'please': 51,
#  'sell': 52,
#  'mexico': 53,
#  'nasty': 54,
#  'flavor': 55,
#  'bargain': 56,
#  'price': 57,
#  'machine': 58,
#  'instant': 59,
#  'oatmeals': 60,
#  'irish': 61,
#  'oatmeal': 62,
#  'hurry': 63,
#  'satisfying': 64,
#  'gluten': 65,
#  'free': 66,
#  'way': 67,
#  'start': 68,
#  'day': 69,
#  'wife': 70,
#  'favorite': 71,
#  'breakfast': 72,
#  'would': 73,
#  'buy': 74,
#  'mcanns': 75,
#  'tastes': 76,
#  'lovers': 77,
#  'convenience': 78,
#  'hearty': 79,
#  'mushy': 80,
#  'next': 81,
#  'time': 82,
#  'order': 83,
#  'variety': 84,
#  'pack': 85,
#  'stuff': 86,
#  'like': 87,
#  'came': 88,
#  'back': 89,
#  'go': 90,
#  'nuts': 91,
#  'ass': 92,
#  'kickin': 93,
#  'peanuts': 94,
#  'roasts': 95,
#  'smooth': 96,
#  'brew': 97,
#  'guests': 98,
#  'awesome': 99,
#  'deal': 100,
#  'wrong': 101,
#  'awsome': 102,
#  'kids': 103,
#  'neighborhood': 104,
#  'loved': 105,
#  'us': 106,
#  'target': 107,
#  'pretty': 108,
#  'stale': 109,
#  'hammer': 110,
#  'nutrition': 111,
#  'fizz': 112,
#  'rocks': 113,
#  'source': 114,
#  'electrolytes': 115,
#  'preventing': 116,
#  'cramps': 117,
#  'low': 118,
#  'carb': 119,
#  'alternative': 120,
#  'gatorade': 121,
#  'much': 122,
#  'pay': 123,
#  'bag': 124,
#  'chocolate': 125,
#  'pretzels': 126,
#  'pretzel': 127,
#  'haven': 128,
#  'gummi': 129,
#  'bigger': 130,
#  'ever': 131,
#  'latice': 132,
#  'tart': 133,
#  'warning': 134,
#  'alcohol': 135,
#  'sugars': 136,
#  'nothing': 137,
#  'special': 138,
#  'tea': 139,
#  'cold': 140,
#  'weather': 141,
#  'forget': 142,
#  'molecular': 143,
#  'gastronomy': 144,
#  'rockes': 145,
#  'coffee': 146,
#  'creamer': 147,
#  'natural': 148,
#  'balance': 149,
#  'lamb': 150,
#  'rice': 151,
#  'increased': 152,
#  'dogs': 153,
#  'itching': 154,
#  'allergies': 155,
#  'stomach': 156,
#  'problems': 157,
#  'life': 158,
#  'sensitive': 159,
#  'mmmmm': 160,
#  'convenient': 161,
#  'allergy': 162,
#  'perfect': 163,
#  'english': 164,
#  'bulldog': 165,
#  'bad': 166,
#  'wise': 167,
#  '6': 168,
#  'star': 169,
#  'item': 170,
#  'support': 171,
#  'omaha': 172,
#  'apple': 173,
#  'tartlets': 174,
#  'disappointing': 175,
#  'wasting': 176,
#  'vinegar': 177,
#  'cucumber': 178,
#  'shame': 179,
#  'asparagus': 180,
#  'bliss': 181,
#  'idea': 182,
#  'angel': 183,
#  'puffs': 184,
#  'every': 185,
#  'green': 186,
#  'freah': 187,
#  'bright': 188,
#  'clean': 189,
#  'review': 190,
#  'cookies': 191,
#  'everyday': 192,
#  'cookie': 193,
#  'far': 194,
#  'cat': 195,
#  'older': 196,
#  'feline': 197,
#  'uti': 198,
#  'palatable': 199,
#  'allergic': 200,
#  'kitties': 201,
#  'holistic': 202,
#  'select': 203,
#  'spicy': 204,
#  'ramen': 205,
#  'burns': 206,
#  'amazing': 207,
#  'last': 208,
#  'bite': 209,
#  'value': 210,
#  'cheaper': 211,
#  'locally': 212,
#  'looks': 213,
#  'beautiful': 214,
#  'happy': 215,
#  'face': 216,
#  'simply': 217,
#  'excellent': 218,
#  'saver': 219,
#  'snack': 220,
#  'licorice': 221,
#  'sized': 222,
#  'kick': 223,
#  'broken': 224,
#  'bottle': 225,
#  'bottoms': 226,
#  'salsa': 227,
#  'ehhh': 228,
#  'cornmeal': 229,
#  'marinade': 230,
#  'rip': 231,
#  'jell': 232,
#  'o': 233,
#  'tasting': 234,
#  'sea': 235,
#  'salt': 236,
#  'iodine': 237,
#  'simple': 238,
#  'greatest': 239,
#  'right': 240,
#  'size': 241,
#  'tasteless': 242,
#  'calorie': 243,
#  'sooooo': 244,
#  'banana': 245,
#  'runts': 246,
#  'heads': 247,
#  'worked': 248,
#  'ricore': 249,
#  'forever': 250,
#  'fluffy': 251,
#  'soft': 252,
#  'sugary': 253,
#  'teen': 254,
#  'lemon': 255,
#  'juice': 256,
#  'handy': 257,
#  'realemon': 258,
#  'amazon': 259,
#  'relaxing': 260,
#  'almost': 261,
#  'something': 262,
#  'smoke': 263,
#  'never': 264,
#  'paid': 265,
#  'marley': 266,
#  'mellow': 267,
#  'mood': 268,
#  'lite': 269,
#  'half': 270,
#  'lemonade': 271,
#  'help': 272,
#  'sleep': 273,
#  'chip': 274,
#  'garbonzo': 275,
#  'bean': 276,
#  'flour': 277,
#  'yum': 278,
#  'falafel': 279,
#  'make': 280,
#  'fruit': 281,
#  'light': 282,
#  'miracle': 283,
#  'ok': 284,
#  'health': 285,
#  'benefits': 286,
#  'arrived': 287,
#  '2': 288,
#  'days': 289,
#  'lunch': 290,
#  'little': 291,
#  'mints': 292,
#  'pricey': 293,
#  'altoids': 294,
#  'mini': 295,
#  'tins': 296,
#  'smalls': 297,
#  'wintergreen': 298,
#  'sugarfree': 299,
#  'reusable': 300,
#  'containers': 301,
#  'huge': 302,
#  'hit': 303,
#  'office': 304,
#  'em': 305,
#  'breath': 306,
#  'average': 307,
#  'loves': 308,
#  'fat': 309,
#  'senior': 310,
#  'citizens': 311,
#  'nearly': 312,
#  'killed': 313,
#  'changed': 314,
#  'formula': 315,
#  'makes': 316,
#  'sick': 317,
#  'case': 318,
#  'looking': 319,
#  'different': 320,
#  'cannot': 321,
#  'correct': 322,
#  'mccormick': 323,
#  'brand': 324,
#  'ahmad': 325,
#  'loose': 326,
#  'imperial': 327,
#  'blend': 328,
#  'fragrant': 329,
#  'real': 330,
#  'bloody': 331,
#  'mary': 332,
#  'mixer': 333,
#  'mcclures': 334,
#  'mix': 335,
#  'really': 336,
#  'give': 337,
#  'watermelon': 338,
#  'citron': 339,
#  'furniture': 340,
#  'polish': 341,
#  'big': 342,
#  'tub': 343,
#  'neutral': 344,
#  'quantity': 345,
#  'deceitful': 346,
#  'eukanuba': 347,
#  'puppy': 348,
#  'small': 349,
#  'breed': 350,
#  'high': 351,
#  'gave': 352,
#  'wicked': 353,
#  'gas': 354,
#  'omg': 355,
#  'jelly': 356,
#  'belly': 357,
#  'anytime': 358,
#  'cup': 359,
#  'get': 360,
#  'store': 361,
#  'disappointed': 362,
#  'kcups': 363,
#  'keeps': 364,
#  'dentest': 365,
#  'chair': 366,
#  'super': 367,
#  'superfoods': 368,
#  'easy': 369,
#  'pok': 370,
#  'chops': 371,
#  'sad': 372,
#  'outcome': 373,
#  'energy': 374,
#  'shot': 375,
#  'waste': 376,
#  'money': 377,
#  'handle': 378,
#  'caffeine': 379,
#  'yummier': 380,
#  'reeks': 381,
#  'chemicals': 382,
#  'lifestyle': 383,
#  'sugar': 384,
#  'raw': 385,
#  'manufacturing': 386,
#  'diminish': 387,
#  'terrible': 388,
#  'agricultural': 389,
#  'practices': 390,
#  'lie': 391,
#  'use': 392,
#  'white': 393,
#  'thanks': 394,
#  'scott': 395,
#  'weak': 396,
#  'packaging': 397,
#  'g': 398,
#  'f': 399,
#  'chips': 400,
#  'priced': 401,
#  'lack': 402,
#  'rotel': 403,
#  'saves': 404,
#  'daily': 405,
#  'basis': 406,
#  'fabulous': 407,
#  'mild': 408,
#  'enough': 409,
#  'lol': 410,
#  'sure': 411,
#  'organic': 412,
#  'fantastic': 413,
#  'guayaki': 414,
#  'provides': 415,
#  'rocket': 416,
#  'works': 417,
#  'boost': 418,
#  'tasted': 419,
#  'tested': 420,
#  'trucker': 421,
#  'drink': 422,
#  'without': 423,
#  'artificial': 424,
#  'ingredients': 425,
#  'getting': 426,
#  'awful': 427,
#  'barely': 428,
#  'describe': 429,
#  'could': 430,
#  'vanilla': 431,
#  'tootsie': 432,
#  'rolls': 433,
#  'one': 434,
#  'favoritte': 435,
#  'foods': 436,
#  'wow': 437,
#  'dissapointed': 438,
#  'swiss': 439,
#  'chalet': 440,
#  'oyster': 441,
#  'absolutely': 442,
#  'gag': 443,
#  'gift': 444,
#  'fast': 445,
#  'penguin': 446,
#  'pooper': 447,
#  'mate': 448,
#  'hazelnut': 449,
#  'creamers': 450,
#  'shipped': 451,
#  'work': 452,
#  'pop': 453,
#  'tarts': 454,
#  'art': 455,
#  'yes': 456,
#  'king': 457,
#  'seasoning': 458,
#  'salts': 459,
#  'toasted': 460,
#  'sesame': 461,
#  'oil': 462,
#  'eating': 463,
#  'whole': 464,
#  'veggie': 465,
#  'brush': 466,
#  'ice': 467,
#  'teething': 468,
#  'difficult': 469,
#  'impressed': 470,
#  'feeder': 471,
#  'beans': 472,
#  'exactly': 473,
#  'expected': 474,
#  'line': 475,
#  'swedish': 476,
#  'pearl': 477,
#  'belgian': 478,
#  'wine': 479,
#  'maker': 480,
#  'olive': 481,
#  'weavers': 482,
#  'fan': 483,
#  'treat': 484,
#  'bitter': 485,
#  'drinking': 486,
#  'latin': 487,
#  'america': 488,
#  'aroma': 489,
#  'bar': 490,
#  'find': 491,
#  'anywhere': 492,
#  'else': 493,
#  'granola': 494,
#  'another': 495,
#  'husband': 496,
#  'surprise': 497,
#  'highly': 498,
#  'recommended': 499,
#  'saving': 500,
#  'grace': 501,
#  'mountain': 502,
#  'nantucket': 503,
#  'k': 504,
#  'cups': 505,
#  'chicken': 506,
#  'noodle': 507,
#  'soup': 508,
#  'since': 509,
#  'slice': 510,
#  'bread': 511,
#  'deliciously': 512,
#  'scrumptious': 513,
#  'heinz': 514,
#  'porcini': 515,
#  'mushrooms': 516,
#  'mostly': 517,
#  'large': 518,
#  'pieces': 519,
#  'highest': 520,
#  'valentine': 521,
#  'winner': 522,
#  'near': 523,
#  'wild': 524,
#  'chick': 525,
#  'brown': 526,
#  'ham': 527,
#  'base': 528,
#  'msg': 529,
#  'delisious': 530,
#  'pancakes': 531,
#  'around': 532,
#  'egg': 533,
#  'arrowhead': 534,
#  'mills': 535,
#  'grain': 536,
#  'buttermilk': 537,
#  'shipping': 538,
#  'soothing': 539,
#  'minty': 540,
#  'take': 541,
#  'seconds': 542,
#  'read': 543,
#  'french': 544,
#  'roast': 545,
#  'n': 546,
#  'bags': 547,
#  'franch': 548,
#  'double': 549,
#  'pleasure': 550,
#  'single': 551,
#  'guy': 552,
#  'acquired': 553,
#  'look': 554,
#  'elsewhere': 555,
#  'grains': 556,
#  'hey': 557,
#  'famous': 558,
#  'reason': 559,
#  'god': 560,
#  'hard': 561,
#  'kettle': 562,
#  'potato': 563,
#  'fully': 564,
#  'loaded': 565,
#  'baked': 566,
#  'lightly': 567,
#  'spiced': 568,
#  'crunchy': 569,
#  'glad': 570,
#  '1': 571,
#  'oz': 572,
#  'slight': 573,
#  'jalapeno': 574,
#  'onion': 575,
#  'ridiculously': 576,
#  'pucker': 577,
#  'thick': 578,
#  'quite': 579,
#  'salty': 580,
#  'vinegary': 581,
#  'dairy': 582,
#  'unique': 583,
#  'thai': 584,
#  'honey': 585,
#  'dijon': 586,
#  'leaves': 587,
#  'aftertaste': 588,
#  'ny': 589,
#  'cheddar': 590,
#  'yowzah': 591,
#  'tangy': 592,
#  'goodness': 593,
#  'heavy': 594,
#  'crisp': 595,
#  'bbq': 596,
#  'cost': 597,
#  'barbeque': 598,
#  'perfection': 599,
#  'flavored': 600,
#  'supreme': 601,
#  'oooh': 602,
#  'want': 603,
#  'gaain': 604,
#  'twenty': 605,
#  'pounds': 606,
#  'control': 607,
#  'whatsoever': 608,
#  'flavors': 609,
#  'addicitive': 610,
#  'become': 611,
#  'chippoisseur': 612,
#  'finally': 613,
#  'superbowl': 614,
#  'scooores': 615,
#  'knees': 616,
#  'cheese': 617,
#  'sour': 618,
#  'cream': 619,
#  'box': 620,
#  'beat': 621,
#  'resist': 622,
#  'spice': 623,
#  'lover': 624,
#  'addictive': 625,
#  'crunchiness': 626,
#  'moisture': 627,
#  '70': 628,
#  'cooked': 629,
#  'used': 630,
#  'firm': 631,
#  'creamy': 632,
#  'chivey': 633,
#  'prefer': 634,
#  'habit': 635,
#  'forming': 636,
#  'even': 637,
#  'already': 638,
#  'oh': 639,
#  'indulgence': 640,
#  'unsalted': 641,
#  'yet': 642,
#  'companions': 643,
#  'wont': 644,
#  'touch': 645,
#  'maybe': 646,
#  'worst': 647,
#  'boulder': 648,
#  'malt': 649,
#  'salted': 650,
#  'heavily': 651,
#  'first': 652,
#  'tongue': 653,
#  'puckering': 654,
#  'tang': 655,
#  'crunch': 656,
#  'period': 657,
#  'extra': 658,
#  'snob': 659,
#  'alert': 660,
#  'gourmet': 661,
#  'powerful': 662,
#  'horrible': 663,
#  'miss': 664,
#  'burnt': 665,
#  'gaaak': 666,
#  'extreme': 667,
#  'absotively': 668,
#  'posilutely': 669,
#  'gone': 670,
#  'hill': 671,
#  'completely': 672,
#  'ripped': 673,
#  'c': 674,
#  'h': 675,
#  'p': 676,
#  'r': 677,
#  'y': 678,
#  'b': 679,
#  'd': 680,
#  'e': 681,
#  'u': 682,
#  'beware': 683,
#  'buying': 684,
#  'rancid': 685,
#  'tiniest': 686,
#  'bit': 687,
#  'disgusting': 688,
#  'strong': 689,
#  'fried': 690,
#  'dripping': 691,
#  'added': 692,
#  'garbage': 693,
#  'madhouse': 694,
#  'munchies': 695,
#  'sold': 696,
#  'damaged': 697,
#  'holes': 698,
#  'stains': 699,
#  'mouse': 700,
#  'orgasmic': 701,
#  'packs': 702,
#  'punch': 703,
#  'cant': 704,
#  'believe': 705,
#  'york': 706,
#  'farts': 707,
#  'smell': 708,
#  'onions': 709,
#  'thing': 710,
#  'addicted': 711,
#  'happened': 712,
#  'recipe': 713,
#  'yoli': 714,
#  'skin': 715,
#  'lips': 716,
#  'sodium': 717,
#  'smiles': 718,
#  'service': 719,
#  'decently': 720,
#  'close': 721,
#  'expiration': 722,
#  'date': 723,
#  'eat': 724,
#  'years': 725,
#  'defacto': 726,
#  'standard': 727,
#  'caution': 728,
#  'kiss': 729,
#  'tummy': 730,
#  'dont': 731,
#  'know': 732,
#  'expired': 733,
#  'stock': 734,
#  'sometimes': 735,
#  '4': 736,
#  'stars': 737,
#  'crispy': 738,
#  'robust': 739,
#  'smaller': 740,
#  'things': 741,
#  'need': 742,
#  'made': 743,
#  'mistake': 744,
#  'vickie': 745,
#  'well': 746,
#  'balanced': 747,
#  'earl': 748,
#  'grey': 749,
#  'success': 750,
#  'shrimp': 751,
#  'stir': 752,
#  'fry': 753,
#  'true': 754,
#  'bavarian': 755,
#  'creme': 756,
#  'oldest': 757,
#  'still': 758,
#  'michigan': 759,
#  '1866': 760,
#  'caramel': 761,
#  'baking': 762,
#  'toppings': 763,
#  'tips': 764,
#  'using': 765,
#  'agave': 766,
#  'weigh': 767,
#  '46': 768,
#  'fluid': 769,
#  'ounces': 770,
#  'sweetner': 771,
#  'syrup': 772,
#  'substitute': 773,
#  'container': 774,
#  'sweetener': 775,
#  'replacing': 776,
#  'nectar': 777,
#  'found': 778,
#  'needs': 779,
#  'ask': 780,
#  'widely': 781,
#  'available': 782,
#  'plocky': 783,
#  'smokey': 784,
#  'chipotle': 785,
#  'tortill': 786,
#  'faboo': 787,
#  'dangerous': 788,
#  'prone': 789,
#  'binges': 790,
#  'grow': 791,
#  'tortilla': 792,
#  'eaten': 793,
#  'got': 794,
#  'country': 795,
#  'instead': 796,
#  'chili': 797,
#  'three': 798,
#  'gum': 799,
#  'stop': 800,
#  'carrying': 801,
#  'om': 802,
#  'nom': 803,
#  'schrumshist': 804,
#  'music': 805,
#  'palate': 806,
#  'kept': 807,
#  'secret': 808,
#  'additive': 809,
#  'fanfreakintastic': 810,
#  'smokin': 811,
#  'red': 812,
#  'meh': 813,
#  'label': 814,
#  'misleading': 815,
#  'kind': 816,
#  'bland': 817,
#  'black': 818,
#  'timely': 819,
#  'delivery': 820,
#  'cute': 821,
#  'surprising': 822,
#  'unparalleled': 823,
#  'side': 824,
#  'perhaps': 825,
#  'batch': 826,
#  'drain': 827,
#  'disappointment': 828,
#  'frosting': 829,
#  'cherrybrook': 830,
#  'kitchen': 831,
#  'dum': 832,
#  'dums': 833,
#  'pops': 834,
#  'fridge': 835,
#  'meat': 836,
#  'anti': 837,
#  'oxidant': 838,
#  'smoothie': 839,
#  'perversion': 840,
#  'annie': 841,
#  'homegrown': 842,
#  'wheat': 843,
#  'shells': 844,
#  'macaroni': 845,
#  'gods': 846,
#  'cuttiest': 847,
#  'century': 848,
#  'city': 849,
#  'steam': 850,
#  'soy': 851,
#  'mainly': 852,
#  'gets': 853,
#  'vote': 854,
#  'though': 855,
#  'kikkoman': 856,
#  'anything': 857,
#  'supermarket': 858,
#  'outstanding': 859,
#  'non': 860,
#  'gmo': 861,
#  'amazingly': 862,
#  'laxative': 863,
#  'joe': 864,
#  'tassimo': 865,
#  'discs': 866,
#  'note': 867,
#  'rating': 868,
#  'seller': 869,
#  'kona': 870,
#  'wafers': 871,
#  'tao': 872,
#  'sampler': 873,
#  'milka': 874,
#  'dad': 875,
#  'liked': 876,
#  'family': 877,
#  'kleri': 878,
#  'cranberries': 879,
#  'ferret': 880,
#  'treats': 881,
#  'edible': 882,
#  'speedy': 883,
#  'sons': 884,
#  '9': 885,
#  '11': 886,
#  'making': 887,
#  'adult': 888,
#  'supervision': 889,
#  'age': 890,
#  'neat': 891,
#  'project': 892,
#  'spongetastic': 893,
#  'twice': 894,
#  'rudolph': 895,
#  'gingerbread': 896,
#  'house': 897,
#  'fun': 898,
#  'paint': 899,
#  'horrid': 900,
#  'buds': 901,
#  'none': 902,
#  'greater': 903,
#  'heaven': 904,
#  'heavenly': 905,
#  'action': 906,
#  'choclate': 907,
#  'serious': 908,
#  '10': 909,
#  'bucks': 910,
#  'overpriced': 911,
#  'gold': 912,
#  '15': 913,
#  'seems': 914,
#  'quick': 915,
#  'arrival': 916,
#  'basket': 917,
#  'adorable': 918,
#  'presentation': 919,
#  'specialty': 920,
#  'party': 921,
#  'liquor': 922,
#  'scottie': 923,
#  'odd': 924,
#  'fake': 925,
#  'sugarless': 926,
#  'stronger': 927,
#  'bubble': 928,
#  'blowing': 929,
#  'gums': 930,
#  'imo': 931,
#  'helps': 932,
#  'weight': 933,
#  'loss': 934,
#  'royal': 935,
#  'canin': 936,
#  'cocker': 937,
#  'cockers': 938,
#  'buster': 939,
#  'human': 940,
#  'rave': 941,
#  'rolled': 942,
#  'oats': 943,
#  'uk': 944,
#  'india': 945,
#  'version': 946,
#  'countries': 947,
#  'cadbury': 948,
#  'mediocre': 949,
#  'cheap': 950,
#  'consistently': 951,
#  'flavorful': 952,
#  'purist': 953,
#  'addict': 954,
#  'fine': 955,
#  'full': 956,
#  'lea': 957,
#  'caramels': 958,
#  'traditional': 959,
#  'soda': 960,
#  'aluminum': 961,
#  'bomb': 962,
#  'interesting': 963,
#  'info': 964,
#  'second': 965,
#  'mm': 966,
#  'funny': 967,
#  'pocky': 968,
#  'sticks': 969,
#  'melt': 970,
#  'japanese': 971,
#  'popping': 972,
#  'dipped': 973,
#  'manga': 974,
#  'local': 975,
#  'wait': 976,
#  'till': 977,
#  'fall': 978,
#  'together': 979,
#  'wanted': 980,
#  'berry': 981,
#  'ones': 982,
#  'lowered': 983,
#  'overall': 984,
#  'child': 985,
#  'wary': 986,
#  'recomended': 987,
#  'bars': 988,
#  'diets': 989,
#  'vile': 990,
#  'strictly': 991,
#  'break': 992,
#  'easily': 993,
#  'twins': 994,
#  'subscription': 995,
#  'fair': 996,
#  'dessert': 997,
#  'nutritional': 998,
#  'repeated': 999,
#  ...}

# %%
source_data  = []
target_data = []
for w in clean_texts :
    words = w.strip().split()
    source_data.append(words)

# %%
for w in clean_summaries :
    words = w.strip().split()
    target_data.append(words)

# %%
target_data
# Out:
# [['good', 'quality', 'dog', 'food'],
#  ['advertised'],
#  ['delight', 'says'],
#  ['cough', 'medicine'],
#  ['great', 'taffy'],
#  ['nice', 'taffy'],
#  ['great', 'good', 'expensive', 'brands'],
#  ['wonderful', 'tasty', 'taffy'],
#  ['yay', 'barley'],
#  ['healthy', 'dog', 'food'],
#  ['best', 'hot', 'sauce', 'world'],
#  ['cats', 'love', 'diet', 'food', 'better', 'regular', 'food'],
#  ['cats', 'fans', 'new', 'food'],
#  ['fresh', 'greasy'],
#  ['strawberry', 'twizzlers', 'yummy'],
#  ['lots', 'twizzlers', 'expect'],
#  ['poor', 'taste'],
#  ['love'],
#  ['great', 'sweet', 'candy'],
#  ['home', 'delivered', 'twizlers'],
#  ['always', 'fresh'],
#  ['twizzlers'],
#  ['delicious', 'product'],
#  ['twizzlers'],
#  ['please', 'sell', 'mexico'],
#  ['twizzlers', 'strawberry'],
#  ['nasty', 'flavor'],
#  ['great', 'bargain', 'price'],
#  ['yummy'],
#  ['best', 'hot', 'sauce', 'world'],
#  ['great', 'machine'],
#  ['taste'],
#  ['best', 'instant', 'oatmeals'],
#  ['good', 'instant'],
#  ['great', 'irish', 'oatmeal', 'hurry'],
#  ['satisfying'],
#  ['love', 'gluten', 'free', 'oatmeal'],
#  ['oatmeal'],
#  ['good', 'way', 'start', 'day'],
#  ['wife', 'favorite', 'breakfast'],
#  ['would', 'buy', 'oatmeal', 'mcanns', 'tastes', 'great'],
#  ['oatmeal', 'oatmeal', 'lovers'],
#  ['food', 'great'],
#  ['good', 'hot', 'breakfast'],
#  ['great', 'taste', 'convenience'],
#  ['hearty', 'oatmeal'],
#  ['good'],
#  ['mushy'],
#  ['good', 'next', 'time', 'order', 'variety', 'pack'],
#  ['stuff'],
#  ['like'],
#  ['hot', 'good', 'came', 'back'],
#  ['go', 'nuts', 'ass', 'kickin', 'peanuts'],
#  ['ass', 'kickin'],
#  ['roasts', 'smooth', 'brew'],
#  ['guests', 'love'],
#  ['awesome', 'deal'],
#  ['go', 'wrong'],
#  ['awsome', 'kids', 'neighborhood', 'loved', 'us'],
#  ['great', 'deal'],
#  ['better', 'price', 'target'],
#  ['pretty', 'expensive'],
#  ['stale', 'product'],
#  ['hammer', 'nutrition', 'fizz', 'rocks'],
#  ['great', 'source', 'electrolytes'],
#  ['great', 'preventing', 'cramps'],
#  ['low', 'carb', 'alternative', 'gatorade'],
#  ['taste', 'good'],
#  ['much', 'would', 'pay', 'bag', 'chocolate', 'pretzels'],
#  ['pretzel', 'haven'],
#  ['great', 'gummi'],
#  ['bigger', 'brands'],
#  ['best', 'ever', 'latice', 'tart'],
#  ['warning', 'warning', 'alcohol', 'sugars'],
#  ['nothing', 'special'],
#  ['tea', 'flavor'],
#  ['good'],
#  ['taste', 'great'],
#  ['order', 'cold', 'weather'],
#  ['best'],
#  ['delicious'],
#  ['great'],
#  ['forget', 'molecular', 'gastronomy', 'stuff', 'rockes', 'coffee', 'creamer'],
#  ['natural', 'balance', 'lamb', 'rice'],
#  ['increased', 'dogs', 'itching'],
#  ['great', 'food'],
#  ['great', 'dogs', 'allergies'],
#  ['great', 'stomach', 'problems'],
#  ['better', 'life', 'dog'],
#  ['great', 'food'],
#  ['great', 'food', 'dog', 'sensitive', 'stomach'],
#  ['great', 'dog', 'food'],
#  ['mmmmm', 'mmmmm', 'good'],
#  ['great', 'dog', 'food'],
#  ['convenient'],
#  ['good', 'healthy', 'dog', 'food'],
#  ['great', 'dog', 'food'],
#  ['great', 'allergy', 'sensitive', 'dog', 'food', 'dogs', 'love'],
#  ['perfect', 'english', 'bulldog', 'allergies'],
#  ['bad'],
#  ['taste', 'wise', '6', 'star', 'item'],
#  ['great', 'support'],
#  ['tart'],
#  ['omaha', 'apple', 'tartlets'],
#  ['loved', 'tartlets'],
#  ['best'],
#  ['disappointing'],
#  ['wasting', 'vinegar', 'cucumber', 'shame'],
#  ['asparagus', 'bliss'],
#  ['idea', 'good', 'diet', 'food'],
#  ['low', 'carb', 'angel', 'food', 'puffs'],
#  ['delicious', 'tea'],
#  ['every', 'day', 'green', 'tea'],
#  ['best', 'tea', 'ever', 'freah', 'bright', 'clean'],
#  ['tea', 'review'],
#  ['wonderful', 'tea'],
#  ['great', 'cookies'],
#  ['best', 'everyday', 'cookie'],
#  ['far', 'good'],
#  ['best', 'cat', 'food'],
#  ['great', 'food'],
#  ['perfect', 'cat', 'food', 'older', 'cats'],
#  ['good', 'feline', 'uti'],
#  ['palatable', 'healthy'],
#  ['healthy', 'love'],
#  ['wonderful', 'food', 'perfect', 'allergic', 'kitties'],
#  ['holistic', 'select', 'cat', 'food'],
#  ['tastes', 'great', 'love', 'hot', 'spicy', 'bad', 'price'],
#  ['favorite', 'ramen'],
#  ['burns'],
#  ['amazing', 'last', 'bite'],
#  [],
#  ['great', 'spicy', 'flavor'],
#  ['great', 'value', 'convenient', 'ramen'],
#  ['great', 'flavor'],
#  ['tastes', 'great', 'cheaper', 'locally'],
#  ['tastes', 'awesome', 'looks', 'beautiful'],
#  ['happy', 'face'],
#  ['simply', 'best'],
#  ['excellent', 'product', 'life', 'saver'],
#  ['nice', 'snack'],
#  ['good', 'licorice'],
#  ['love'],
#  ['great', 'kids'],
#  ['bite', 'sized'],
#  ['sweet', 'nice', 'kick'],
#  ['broken', 'bottle', 'bottoms'],
#  ['love', 'salsa'],
#  ['ehhh'],
#  ['awesome', 'cornmeal'],
#  ['great', 'marinade'],
#  ['awesome', 'stuff'],
#  ['tastes', 'good'],
#  ['rip', 'price'],
#  ['jell', 'o'],
#  ['great', 'flavor', 'jell', 'o'],
#  ['great', 'deal'],
#  ['great', 'tasting', 'sea', 'salt', 'iodine'],
#  ['tastes', 'fresh'],
#  ['simple', 'good'],
#  ['tasty'],
#  ['greatest', 'tasting'],
#  ['bad'],
#  ['right', 'size', 'taste'],
#  ['tasteless', 'low', 'calorie'],
#  ['stuff', 'sooooo', 'good'],
#  ['best', 'stuff', 'ever'],
#  ['low', 'quality'],
#  ['banana', 'runts'],
#  ['banana', 'heads', 'banana', 'runts'],
#  ['worked', 'great'],
#  ['ricore', 'forever'],
#  ['delicious'],
#  ['fluffy', 'soft', 'delicious', 'sugary', 'sweet'],
#  ['great', 'good', 'back', 'day', 'teen'],
#  ['excellent', 'lemon', 'juice'],
#  ['great', 'product'],
#  ['handy'],
#  ['realemon', 'juice', 'amazon'],
#  ['relaxing', 'almost', 'like', 'something', 'smoke'],
#  ['never', 'paid', 'much'],
#  ['marley', 'mellow', 'mood', 'lite', 'half', 'tea', 'half', 'lemonade'],
#  ['great', 'product', 'help', 'sleep'],
#  ['perfect', 'gluten', 'free', 'chocolate', 'chip', 'cookies'],
#  ['garbonzo', 'bean', 'flour'],
#  ['yum', 'falafel'],
#  ['make', 'fresh', 'fruit', 'tart', 'light', 'beautiful'],
#  ['miracle'],
#  ['bad', 'instant', 'healthy', 'coffee'],
#  ['ok'],
#  ['love'],
#  ['great', 'taste', 'health', 'benefits'],
#  ['tastes', 'great', 'arrived', '2', 'days'],
#  ['great', 'lunch'],
#  ['nice', 'little', 'mints', 'pricey'],
#  ['altoids', 'mini', 'mints', 'tins'],
#  ['altoids', 'smalls', 'wintergreen'],
#  ['sugarfree'],
#  ['tasty'],
#  ['mints', 'awesome'],
#  ['altoids', 'smalls'],
#  ['love', 'reusable', 'containers'],
#  ['altoids'],
#  ['huge', 'hit', 'office'],
#  ['love', 'em', 'great'],
#  ['love'],
#  ['fresh'],
#  ['wintergreen'],
#  ['breath', 'mints'],
#  ['better', 'average', 'expensive', 'average'],
#  ['cat', 'loves'],
#  ['great', 'fat', 'cats', 'senior', 'citizens'],
#  ['nearly', 'killed', 'cats'],
#  ['changed', 'formula', 'makes', 'cats', 'sick'],
#  ['best', 'case'],
#  ['looking', 'different', 'flavor'],
#  ['price', 'cannot', 'correct'],
#  ['hot', 'spicy', 'mccormick', 'brand'],
#  ['ahmad', 'loose', 'imperial', 'blend', 'tea', 'great', 'price'],
#  ['nice', 'tea'],
#  ['fragrant', 'tea'],
#  ['best', 'ahmad', 'tea'],
#  ['favorite', 'tea'],
#  ['best', 'tea', 'ever'],
#  ['real', 'tea'],
#  ['delicious'],
#  ['best', 'bloody', 'mary', 'mixer'],
#  ['best'],
#  ['mcclures', 'bloody', 'mary', 'mix'],
#  ['good'],
#  ['love', 'tea'],
#  ['really', 'nice', 'taste'],
#  ['give', 'watermelon', 'citron', 'sea', 'salt'],
#  ['furniture', 'polish', 'taste'],
#  ['big', 'tub', 'o', 'salt'],
#  ['taste', 'neutral', 'quantity', 'deceitful'],
#  ['eukanuba', 'puppy', 'small', 'breed', 'dog', 'food'],
#  ['high', 'quality', 'gave', 'dog', 'wicked', 'gas'],
#  ['great', 'tasting', 'green', 'tea', 'great', 'deal'],
#  ['omg', 'best', 'chocolate', 'jelly', 'belly'],
#  ['excellent', 'loose', 'tea'],
#  ['good', 'anytime', 'hot', 'tea'],
#  ['everyday', 'cup', 'tea'],
#  ['get', 'store'],
#  ['ahmad', 'tea'],
#  ['disappointed'],
#  ['wonderful'],
#  ['best', 'way', 'buy', 'kcups'],
#  ['delicious'],
#  ['keeps', 'dentest', 'chair'],
#  ['super', 'superfoods', 'super', 'easy'],
#  ['pok', 'chops'],
#  ['sad', 'outcome'],
#  ['best', 'energy', 'shot'],
#  ['waste', 'money'],
#  ['cannot', 'handle', 'caffeine'],
#  ['yum', 'yummy', 'yummier'],
#  ['reeks', 'like', 'chemicals'],
#  ['disappointed'],
#  ['great', 'gluten', 'free', 'lifestyle'],
#  ['dog', 'loves'],
#  ['yummy'],
#  ['sugar', 'raw'],
#  ['manufacturing', 'problems', 'diminish', 'product'],
#  ['good', 'product', 'terrible', 'agricultural', 'practices'],
#  ['sugar', 'raw'],
#  ['sugar', 'raw'],
#  ['lie'],
#  ['sugar'],
#  ['excellent', 'perfect'],
#  ['good', 'product'],
#  ['never', 'use', 'white', 'sugar'],
#  ['thanks', 'review', 'scott'],
#  ['great'],
#  ['awesome', 'sugar'],
#  ['great', 'product', 'weak', 'packaging'],
#  ['excellent'],
#  ['excellent', 'g', 'f'],
#  ['amazing'],
#  ['tasty', 'chips'],
#  ['yummy'],
#  ['excellent', 'taste'],
#  ['priced', 'chips', 'lack', 'rice', 'taste'],
#  ['rotel', 'saves', 'daily', 'basis'],
#  ['fabulous', 'amazon'],
#  ['expensive'],
#  ['mild', 'enough', 'lol'],
#  ['great', 'natural', 'energy'],
#  ['like', 'stuff'],
#  ['great', 'energy'],
#  ['sure'],
#  ['best', 'energy', 'shot', 'smooth', 'organic'],
#  ['fantastic', 'natural', 'energy'],
#  ['way', 'better', 'guayaki'],
#  ['taste', 'good', 'provides', 'energy'],
#  ['rocket', 'bottle'],
#  ['stuff', 'works'],
#  ['favorite', 'energy', 'shot', 'natural'],
#  ['natural', 'energy', 'boost'],
#  ['best', 'energy', 'shot', 'ever', 'tasted'],
#  ['best'],
#  ['tested', 'trucker'],
#  ['good', 'stuff'],
#  ['great', 'energy', 'drink', 'without', 'artificial', 'ingredients'],
#  ['flavor', 'getting', 'better', 'energy', 'great'],
#  ['awful', 'barely', 'describe'],
#  ['could', 'use'],
#  ['vanilla', 'tootsie', 'rolls'],
#  ['one', 'favoritte', 'foods'],
#  ['fantastic'],
#  ['wow'],
#  ['dissapointed'],
#  ['quantity'],
#  ['good', 'coffee'],
#  ['tasty'],
#  ['excellent', 'coffee'],
#  ['hot'],
#  ['hot', 'delicious'],
#  ['swiss', 'chalet'],
#  ['oyster', 'sauce'],
#  ['absolutely', 'delicious'],
#  ['great', 'gag', 'gift'],
#  ['arrived', 'fast'],
#  ['penguin', 'pooper'],
#  ['never', 'arrived'],
#  ['coffee', 'mate', 'coffee', 'creamer', 'hazelnut'],
#  ['broken', 'creamers'],
#  ['shipped', 'great'],
#  ['better', 'packaging'],
#  ['coffee', 'mate', 'creamer'],
#  ['perfect', 'work'],
#  ['awful'],
#  ['pop', 'tarts', 'work', 'art'],
#  ['yes', 'real', 'excellent', 'coffee'],
#  ['taste', 'good'],
#  [],
#  ['king', 'seasoning', 'salts'],
#  ['toasted', 'sesame', 'oil'],
#  ['tasty', 'tasty', 'tasty'],
#  ['love', 'love', 'love'],
#  ['great', 'eating', 'whole', 'foods', 'clean', 'veggie', 'brush'],
#  ['absolutely', 'love'],
#  ['good', 'ice'],
#  ['great', 'teething'],
#  ['wonderful', 'idea', 'difficult', 'clean'],
#  ['impressed'],
#  ['love', 'fresh', 'food', 'feeder'],
#  ['great', 'beans'],
#  ['good', 'stuff'],
#  ['excellent', 'exactly', 'expected'],
#  ['best'],
#  ['love', 'love', 'love'],
#  ['product', 'great', 'price', 'line'],
#  ['swedish', 'pearl', 'belgian', 'pearl'],
#  ['perfect'],
#  ['great', 'taste'],
#  ['taste', 'tested', 'wine', 'maker'],
#  ['excellent', 'everyday', 'olive', 'oil'],
#  ['love', 'weavers', 'fan'],
#  ['make', 'day'],
#  ['treat', 'best', 'coffee'],
#  ['bitter'],
#  ['drinking', 'love', 'latin', 'america', 'aroma'],
#  ['great', 'snack'],
#  ['best', 'bar'],
#  ['cannot', 'find', 'anywhere', 'else'],
#  ['new', 'granola', 'bar'],
#  ['another', 'husband', 'favorite'],
#  ['price', 'surprise'],
#  ['smooth', 'coffee', 'highly', 'recommended'],
#  ['saving', 'grace', 'green', 'mountain', 'coffee'],
#  ['favorite'],
#  ['good', 'coffee'],
#  ['nantucket', 'blend', 'k', 'cups'],
#  ['fantastic', 'chicken', 'noodle', 'soup'],
#  ['greatest', 'oil', 'since', 'slice', 'bread'],
#  ['best', 'ever'],
#  ['deliciously', 'scrumptious'],
#  ['heinz'],
#  ['really', 'good', 'stuff'],
#  ['disappointing'],
#  ['waste', 'money'],
#  ['porcini', 'mushrooms', 'excellent', 'product'],
#  ['excellent', 'flavor', 'mostly', 'large', 'pieces'],
#  ['best'],
#  ['good', 'money'],
#  ['highest', 'quality', 'good', 'price'],
#  ['fresh', 'whole', 'perfect'],
#  ['fresh', 'tasty'],
#  ['valentine', 'gift', 'winner'],
#  ['cat', 'go', 'near'],
#  ['simply', 'wild', 'chick', 'brown', 'rice', 'cats'],
#  ['ham', 'base'],
#  ['msg', 'ham', 'base'],
#  ['delisious', 'pancakes'],
#  ['great', 'around', 'mix'],
#  ['great', 'mix'],
#  ['perfect', 'mix', 'egg', 'allergic'],
#  ['arrowhead', 'mills', 'whole', 'grain', 'buttermilk', 'pancakes', 'easy'],
#  ['good', 'egg', 'allergy'],
#  ['love', 'product', 'disappointed', 'shipping'],
#  ['poor', 'item', 'packaging'],
#  ['awful'],
#  ['disappointing'],
#  ['great', 'healthy', 'snack'],
#  ['sweet', 'soothing'],
#  ['minty', 'flavor'],
#  ['ingredients', 'take', '2', 'seconds', 'read'],
#  ['fantastic', 'healthy', 'product'],
#  ['great', 'product'],
#  ['excellent', 'tea'],
#  ['french', 'roast', 'n', 'bags'],
#  ['best', 'roast', 'ever'],
#  ['franch', 'best'],
#  ['double', 'pleasure'],
#  ['good', 'great', 'taste', 'easy', 'single', 'guy'],
#  ['acquired', 'taste'],
#  ['look', 'elsewhere', 'whole', 'grains'],
#  ['hey'],
#  ['famous', 'reason'],
#  ['wow'],
#  ['god', 'love', 'cookies'],
#  ['hard'],
#  ['kettle', 'potato', 'chips', 'fully', 'loaded', 'baked', 'potato'],
#  ['fresh',
#   'lightly',
#   'spiced',
#   'crunchy',
#   'kettle',
#   'chips',
#   'good',
#   'value',
#   'good',
#   'product'],
#  ['glad', 'find', '1', 'oz', 'size'],
#  ['pretty', 'good', 'could', 'better'],
#  ['slight', 'taste', 'jalapeno'],
#  ['best', 'chips', 'ever'],
#  ['kettle', 'potato', 'chips', 'sweet', 'onion'],
#  ['ridiculously', 'good'],
#  ['delicious'],
#  ['pucker'],
#  ['love', 'chips', 'thick', 'crunchy'],
#  ['quite', 'good'],
#  ['delicious'],
#  ['salty', 'vinegary'],
#  ['wow'],
#  ['best', 'gluten', 'free', 'dairy', 'free', 'chips'],
#  ['unique', 'flavor', 'fans', 'thai', 'food'],
#  ['honey',
#   'dijon',
#   'leaves',
#   'bad',
#   'aftertaste',
#   'ny',
#   'cheddar',
#   'pretty',
#   'good'],
#  ['yowzah'],
#  ['good'],
#  ['excellent'],
#  ['tangy', 'goodness'],
#  ['heavy', 'vinegar'],
#  ['delicious', 'crisp', 'chip', 'good', 'flavor'],
#  ['best', 'buy', 'bbq', 'chips'],
#  ['love'],
#  ['crunchy', 'tasty'],
#  ['convenience', 'low', 'cost'],
#  ['acquired', 'taste'],
#  ['best', 'deal', 'ever'],
#  ['yum'],
#  ['barbeque', 'perfection'],
#  ['excellent', 'thai', 'flavored', 'chip'],
#  ['best', 'kettle', 'chips'],
#  ['supreme', 'salt', 'vinegar'],
#  ['delicious', 'always'],
#  ['oooh', 'yummy'],
#  ['quite', 'best'],
#  ['want', 'gaain', 'twenty', 'pounds', 'control', 'whatsoever', 'buy'],
#  ['one', 'best', 'flavors'],
#  ['love', 'chips'],
#  ['highly', 'addicitive', 'chips'],
#  ['awesome'],
#  ['one', 'bite', 'become', 'chippoisseur'],
#  ['crunchy', 'salty', 'sweet', 'finally', 'superbowl', 'snack', 'scooores'],
#  ['chips', 'make', 'weak', 'knees'],
#  ['far', 'favorite', 'chips'],
#  ['good', 'chips', 'cheese'],
#  ['pretty', 'good', 'tasting', 'chip'],
#  ['yummy', 'chips'],
#  ['best', 'sour', 'cream', 'onion', 'chip'],
#  ['great', 'chips'],
#  ['fabulous'],
#  ['box', 'o', 'chips'],
#  ['fantastic', 'beat', 'taste', 'resist', 'one', 'spice', 'lover'],
#  ['addictive', 'potato', 'chip'],
#  ['great', 'chip'],
#  ['excellent', 'balance', 'taste', 'crunchiness', 'moisture'],
#  ['yum'],
#  ['good', 'chips', 'great', 'price'],
#  ['70', 'chips', 'bag', 'cooked'],
#  ['great', 'chips'],
#  ['bad', 'little', 'hard', 'get', 'used'],
#  ['firm', 'quality', 'chip'],
#  ['creamy', 'chivey'],
#  ['prefer', 'flavors'],
#  ['habit', 'forming'],
#  ['good', 'tangy'],
#  ['best', 'chips', 'ever'],
#  ['even', 'like', 'kettle', 'chips', 'love'],
#  ['love', 'sea', 'salt', 'vinegar', 'already'],
#  ['addictive'],
#  ['amazing', 'chips'],
#  ['best', 'chip', 'ever'],
#  ['tangy', 'spicy', 'sweet', 'oh'],
#  ['indulgence', 'bite'],
#  ['best'],
#  ['excellent', 'chip'],
#  ['salt', 'vinegar', 'chips'],
#  ['delicious'],
#  ['like'],
#  ['love', 'kettle', 'chips'],
#  ['best', 'unsalted', 'chips'],
#  ['delicious', 'yet', 'companions', 'wont', 'touch'],
#  ['love', 'kettle', 'chips', 'flavor'],
#  ['maybe', 'worst', 'chips', 'ever'],
#  ['surprise', '1', 'different'],
#  ['tasty'],
#  ['crisp'],
#  ['vinegar', 'taste'],
#  ['spicy', 'thai', 'chips'],
#  ['delicious', 'else', 'expect'],
#  ['great', 'value'],
#  ['better', 'jalapeno', 'kettle', 'chips'],
#  ['spicy', 'good'],
#  ['boulder', 'salt', 'malt', 'vinegar', 'chips', 'way', 'better'],
#  ['potato', 'chips'],
#  ['lightly', 'salted', 'heavily', 'delicious'],
#  ['much', 'flavor'],
#  ['love', 'first', 'bite', 'tongue', 'puckering', 'tang', 'crunch'],
#  ['best', 'chips', 'period'],
#  ['delicious', 'extra', 'crunchy'],
#  ['chip', 'snob', 'alert'],
#  ['best', 'salt', 'vinegar'],
#  ['gourmet', 'powerful', 'salt', 'vinegar', 'chips'],
#  ['changed', 'chips', 'taste', 'horrible'],
#  ['miss', 'salt'],
#  ['great', 'deal'],
#  ['best', 'chips'],
#  ['great', 'price', 'tangy', 'expected'],
#  ['burnt'],
#  ['gaaak', 'extreme', 'potato', 'chip'],
#  ['kettle', 'chips'],
#  ['absotively', 'posilutely', 'delicious'],
#  ['gone', 'hill'],
#  ['completely', 'ripped'],
#  ['c',
#   'h',
#   'p',
#   'c',
#   'h',
#   'p',
#   'h',
#   'o',
#   'o',
#   'r',
#   'y',
#   'b',
#   'c',
#   'k',
#   'y',
#   'r',
#   'd',
#   'b',
#   'r',
#   'b',
#   'e',
#   'c',
#   'u',
#   'e'],
#  ['best'],
#  ['stale', 'beware', 'buying', 'special'],
#  ['good'],
#  ['used', 'favorite', 'chips'],
#  ['stale',
#   'rancid',
#   'oil',
#   'taste',
#   'like',
#   'even',
#   'tiniest',
#   'bit',
#   'salt',
#   'flavor',
#   'chips'],
#  ['disgusting'],
#  ['taste', 'terrible', 'way', 'strong'],
#  ['fried'],
#  ['salt', 'kettle', 'chips'],
#  ['good', 'english', 'sell'],
#  ['disappointed'],
#  ['dripping', 'oil'],
#  ['good'],
#  ['bags', 'o', 'salt', 'chips', 'added'],
#  ['chips'],
#  ['garbage'],
#  ['madhouse', 'munchies'],
#  ['sour'],
#  ['awful', 'taste'],
#  ['delicious'],
#  ['kettle', 'sold', 'chips', 'horrible'],
#  ['bags', 'damaged', 'holes', 'stains'],
#  ['kettle', 'chips', 'make', 'great', 'mouse', 'food'],
#  ['orgasmic'],
#  ['tang', 'packs', 'punch'],
#  ['great', 'hot', 'new', 'flavor'],
#  ['horrible', 'cant', 'believe'],
#  ['favorite', 'kettle', 'flavor', 'great', 'value'],
#  ['kettle', 'brand', 'potato', 'chips', 'new', 'york', 'cheddar'],
#  ['favorite', 'flavor'],
#  ['much', 'flavor', 'farts', 'smell', 'like', 'sweet', 'onions'],
#  ['great', 'chip'],
#  ['awesome', 'delicious'],
#  ['thing', 'ever', 'addicted', 'chips'],
#  ['one', 'bite', 'become', 'chippoisseur'],
#  ['good', 'chips'],
#  ['happened', 'recipe', 'changed'],
#  ['yum', 'want', 'snack', 'something', 'really', 'good'],
#  ['good', 'buy'],
#  ['yoli'],
#  ['good', 'chips'],
#  ['awesome'],
#  ['burns', 'skin', 'lips'],
#  ['great', 'chips', 'low', 'sodium'],
#  ['kettle', 'chips'],
#  ['spicy', 'thai'],
#  ['smiles'],
#  ['favorite', 'kettle', 'chip'],
#  ['best', 'salt', 'vinegar', 'chips'],
#  ['amazing', 'service'],
#  ['crunchy', 'spicy'],
#  ['pretty', 'tasty', 'decently', 'spiced'],
#  ['great', 'tasting', 'chips'],
#  ['kettle', 'chips', 'sea', 'salt'],
#  ['good', 'deal', 'close', 'expiration', 'date'],
#  ['great', 'tasting', 'chips'],
#  ['buy', 'eat', 'happy'],
#  ['eating', 'years'],
#  ['chips', 'make', 'fat'],
#  ['like', 'spice', 'get'],
#  ['fantastic'],
#  ['sweet', 'salty', 'tangy', 'way', 'snack'],
#  ['one', 'bite', 'become', 'chippoisseur'],
#  ['one', 'bite', 'become', 'chippoisseur'],
#  ['best', 'chips', 'anywhere'],
#  ['defacto', 'standard', 'salt', 'vinegar', 'chips'],
#  ['yummy'],
#  ['delicious'],
#  ['lightly', 'salted', 'yet', 'tasty'],
#  ['yummy'],
#  ['caution', 'kettle', 'chips', 'addictive'],
#  ['chip', 'kiss', 'salt'],
#  ['crunch', 'wow'],
#  ['great', 'strong', 'flavor'],
#  ['yummy', 'tummy'],
#  ['best', 'chips'],
#  ['chips', 'tasted', 'good'],
#  ['awesome', 'chips'],
#  ['dont', 'know'],
#  ['delicious'],
#  ['kettle', 'foods', 'spicy', 'thai', 'chips'],
#  ['expired', 'stock'],
#  ['potato', 'chips', 'yummy'],
#  ['awful', 'sometimes', 'awful'],
#  ['4', 'stars', 'price', 'taste'],
#  ['crispy', 'crunchy', 'robust'],
#  ['tangy', 'delicious', 'snack'],
#  ['best', 'chip'],
#  ['low', 'salt'],
#  ['best', 'chips', 'ever', 'tasted'],
#  ['tasty'],
#  ['love', 'smaller', 'bags'],
#  ['things', 'need', 'know'],
#  ['made', 'mistake'],
#  ['ok', 'miss', 'vickie', 'better'],
#  ['bite', 'back'],
#  ['chips', 'awesome', 'best'],
#  ['kettle', 'chips'],
#  ['great', 'deal'],
#  ['great', 'tea', 'price'],
#  ['delicious'],
#  ['great', 'well', 'balanced', 'earl', 'grey'],
#  ['best', 'earl', 'grey', 'ever'],
#  ['favorite', 'earl', 'grey', 'tea'],
#  ['delicious'],
#  ['best'],
#  ['huge', 'success'],
#  ['health'],
#  ['shrimp', 'stir', 'fry'],
#  ['taste', 'bottle', 'mix', 'vanilla', 'true', 'flavor'],
#  ['bavarian', 'creme', 'flavor', 'oil'],
#  ['oldest', 'soft', 'drink', 'still', 'best'],
#  ['made', 'michigan', 'since', '1866'],
#  ['caramel',
#   'flavor',
#   'excellent',
#   'baking',
#   'toppings',
#   'tips',
#   'using',
#   'agave'],
#  ['weigh', '46', 'oz', '46', 'fluid', 'ounces'],
#  ['great', 'buy'],
#  ['excellent', 'sweetner'],
#  ['agave', 'syrup'],
#  ['sugar', 'substitute'],
#  ['good', 'container', 'could', 'better'],
#  ['great', 'stuff'],
#  ['healthy', 'sweetener'],
#  ['great', 'way', 'replacing', 'sugar'],
#  ['great', 'substitute', 'sweetener'],
#  ['go', 'sweetner'],
#  ['best'],
#  ['yummy'],
#  ['healthy', 'stuff'],
#  ['agave', 'nectar'],
#  ['sweet', 'success'],
#  ['great', 'product'],
#  ['best', 'price', 'agave', 'nectar', 'found'],
#  ['could', 'good'],
#  ['best', 'tea', 'ever'],
#  ['spicy'],
#  ['needs', 'salsa', 'chips', 'taste', 'good'],
#  ['delicious'],
#  ['organic', 'yummy', 'chips', 'ask'],
#  ['different', 'flavor'],
#  ['best', 'widely', 'available', 'bbq', 'chips'],
#  ['favorite', 'chips', 'kettle'],
#  ['amazing', 'taste', 'best', 'chip', 'ever'],
#  ['tasty'],
#  ['plocky', 'sweet', 'smokey', 'chipotle', 'whole', 'grain', 'tortill'],
#  ['yummy', 'chips'],
#  ['tasty'],
#  ['faboo', 'dangerous', 'prone', 'chips', 'binges'],
#  ['spice', 'grow'],
#  ['best', 'tortilla', 'chips', 'ever', 'eaten'],
#  ['excellent', 'chip'],
#  ['wrong', 'flavor', 'got', 'country', 'bbq', 'instead', 'chili', 'chipotle'],
#  ['great'],
#  ['plocky', 'rice', 'beans', 'tortilla', 'chips'],
#  ['huge', 'fan', 'chips'],
#  ['plocky', 'tortilla', 'chips', 'tasty', 'healthy'],
#  ['plocky', 'three', 'grain', 'tortilla', 'chips'],
#  ['tasty', 'make', 'sure', 'gum'],
#  ['stop', 'carrying', 'chips'],
#  ['om', 'nom', 'nom', 'nom'],
#  ['delicious', 'healthy'],
#  ['unique', 'schrumshist', 'tasty', 'tortilla', 'chips'],
#  ['music', 'palate'],
#  ['yummy'],
#  ['kettle', 'organic', 'chipotle', 'potato', 'chips'],
#  ['best', 'kept', 'secret'],
#  ['delicious', 'additive'],
#  ['fanfreakintastic'],
#  ['smokin'],
#  ['really', 'good', 'chips'],
#  ['plocky', 'tortilla', 'chips', 'red', 'beans', 'n', 'rice'],
#  ['simply', 'best'],
#  ['addicted'],
#  ['perfect', 'tortilla', 'chip', 'goodness'],
#  ['chips', 'addictive'],
#  ['best', 'tortilla', 'chips', 'ever'],
#  ['meh'],
#  ['organic', 'label', 'misleading'],
#  ['kind', 'bland'],
#  ['delicious', 'chips'],
#  ['broken', 'chips', 'tasty'],
#  ['best', 'chips', 'ever'],
#  ['excellent', 'tortilla', 'chips'],
#  ['black', 'beans', 'never', 'tasted', 'good'],
#  ['favorite', 'chip'],
#  ['timely', 'delivery'],
#  ['tasty', 'beware'],
#  ['great', 'candy'],
#  ['candy'],
#  ['cute', 'cute', 'cute'],
#  ['surprising', 'find'],
#  ['unparalleled', 'taste'],
#  ['amazing'],
#  ['bit', 'stale', 'side'],
#  ['delicious'],
#  ['disappointed'],
#  ['perhaps', 'something', 'wrong', 'batch'],
#  ['4', 'drain'],
#  ['big', 'disappointment'],
#  ['worst', 'frosting', 'ever'],
#  ['worst', 'frosting', 'ever'],
#  ['cherrybrook', 'kitchen', 'vanilla', 'frosting'],
#  ['buy', 'frosting'],
#  ['dum', 'dums'],
#  ['lots', 'pops'],
#  ['fridge', 'want', 'meat'],
#  ['anti', 'oxidant', 'smoothie'],
#  ['perversion', 'taste'],
#  ['annie',
#   'homegrown',
#   'organic',
#   'whole',
#   'wheat',
#   'shells',
#   'white',
#   'cheddar',
#   'macaroni',
#   'cheese',
#   '6',
#   'oz'],
#  ['flavor', 'gods'],
#  ['cuttiest', 'gum', 'century'],
#  ['city', 'steam', 'much', 'steam', 'brew'],
#  ['good', 'soy', 'sauce', 'special', 'mainly', 'good', 'unique', 'gift'],
#  ['surprise'],
#  ['gets', 'vote'],
#  ['though', 'kikkoman', 'good'],
#  ['better', 'anything', 'supermarket'],
#  ['best', 'soy', 'sauce', 'ever'],
#  ['great', 'sauce'],
#  ['outstanding', 'product'],
#  ['non', 'gmo'],
#  ['amazingly', 'true', 'flavors'],
#  ['laxative'],
#  ['good', 'tasting', 'cup', 'o', 'joe'],
#  ['best', 'tassimo'],
#  ['great', 'coffee', 'terrible', 'price'],
#  ['one', 'better', 'discs'],
#  ['note', 'rating', 'coffee', 'seller'],
#  ['kona', 'tassimo'],
#  ['best', 'wafers'],
#  ['tao', 'tea', 'get'],
#  ['perfect', 'sampler', 'milka', 'chocolate'],
#  ['dad', 'really', 'liked'],
#  ['great', 'candy', 'family', 'loved'],
#  ['yummy'],
#  ['horrible', 'dont', 'buy'],
#  ['kleri', 'tea', 'works', 'great'],
#  ['cranberries'],
#  ['ferret', 'loves'],
#  ['fantastic'],
#  ['great', 'little', 'treats'],
#  ['edible'],
#  ['speedy', 'shipping'],
#  ['sons',
#   '9',
#   '11',
#   'loved',
#   'making',
#   'easy',
#   'enough',
#   'adult',
#   'supervision',
#   'age',
#   'neat',
#   'project'],
#  ['spongetastic'],
#  ['easy', 'looks'],
#  ['one', 'twice', 'came', 'broken'],
#  ['rudolph', 'gingerbread', 'house'],
#  ['fun', 'paint'],
#  ['disappointment'],
#  ['cute', 'item', 'expired'],
#  ['could', 'give', 'rating', 'one', 'star'],
#  ['horrid'],
#  ['delicious'],
#  ['love', 'tea', 'taste', 'buds'],
#  ['none', 'greater'],
#  ['caramel', 'chocolate'],
#  ['chocolate', 'heaven'],
#  ['heavenly', 'action'],
#  ['great', 'chocolate'],
#  ['great', 'item'],
#  ['choclate'],
#  ['serious', '10', 'bucks'],
#  ['yum'],
#  ['overpriced', 'even', 'gold', 'box'],
#  ['even', '15', 'seems', 'little', 'overpriced'],
#  ['quick', 'arrival', 'great', 'basket'],
#  ['adorable', 'basket', 'makes', 'nice', 'presentation'],
#  ['specialty', 'party', 'item'],
#  ['delicious'],
#  ['chocolate', 'go', 'wrong'],
#  ['chocolate', 'liquor', 'cups'],
#  ['scottie'],
#  ['good', 'flavor'],
#  ['odd', 'fake', 'flavor', 'recommended'],
#  ['good',
#   'sugarless',
#   'gum',
#   'stronger',
#   'gum',
#   'better',
#   'bubble',
#   'blowing',
#   'sugarless',
#   'gums'],
#  ['great', 'gum'],
#  ['delicious', 'imo', 'helps', 'weight', 'loss'],
#  ['royal', 'canin', 'cocker'],
#  ['perfect', 'cockers'],
#  ['dog', 'loves', 'food'],
#  ['great', 'deal'],
#  ['great', 'food'],
#  ['buster', 'loves', 'dog', 'food'],
#  ['happy', 'dogs'],
#  ['fast', 'great', 'service'],
#  ['good', 'food'],
#  ['happy', 'dog'],
#  ['great', 'way', 'order'],
#  ['good', 'quality', 'delivered', 'time', 'human', 'edible'],
#  ['rave', 'review', 'rolled', 'oats'],
#  ['excellent'],
#  ['different', 'taste', 'made', 'uk', 'made', 'india', 'version'],
#  ['like', 'countries', 'cadbury'],
#  ['great', 'deal', 'great', 'tea'],
#  ['best', 'breakfast', 'tea', 'ever'],
#  ['great', 'organic', 'tea', 'great', 'price'],
#  ['mediocre', 'cheap'],
#  ['delicious', 'consistently', 'good', 'quality'],
#  ['nice', 'flavorful', 'tea', 'purist', 'black', 'tea', 'addict'],
#  ['best', 'tea'],
#  ['great', 'tea'],
#  ['fine', 'tasting', 'full', 'lea', 'great', 'value'],
#  ['creamy'],
#  ['caramel', 'fantastic'],
#  ['great', 'caramels'],
#  ['candy'],
#  ['traditional', 'caramel', 'lovers'],
#  ['soda'],
#  ['aluminum', 'free'],
#  ['baking', 'soda', 'bomb'],
#  ['interesting', 'info', 'baking', 'soda'],
#  ['excellent', 'quality', 'product', 'fast', 'delivery'],
#  ['good', 'oatmeal', 'second', 'bag'],
#  ['mm', 'mm', 'oats'],
#  ['loved', 'oats'],
#  ['funny', 'taste'],
#  ['awsome'],
#  ['happy', 'pocky', 'sticks'],
#  ['great'],
#  ['love', 'snack'],
#  ['chocolate', 'melt'],
#  ['item', 'awesome'],
#  ['great', 'tasting', 'snack', 'get', 'japanese', 'pocky'],
#  ['great', 'product'],
#  ['delicious'],
#  ['fun',
#   'popping',
#   'crispy',
#   'sticks',
#   'dipped',
#   'chocolate',
#   'special',
#   'treat',
#   'manga',
#   'fans',
#   'find',
#   'local',
#   'wait',
#   'till',
#   'fall'],
#  ['yummy'],
#  ['taste'],
#  ['pocky'],
#  ['great', 'buy'],
#  ['good', 'stuff'],
#  ['pocky', 'sticks', 'together'],
#  ['really', 'wanted', 'like'],
#  ['good', 'berry', 'flavor', 'excellent', 'price'],
#  ['chocolate', 'ones', 'much', 'better'],
#  ['something', 'changed'],
#  ['good', 'berry', 'flavor'],
#  ['great', 'taste', 'size', 'smaller'],
#  ['cheaper', 'ingredients', 'lowered', 'quality'],
#  ['fan'],
#  ['perfect', 'size'],
#  ['pretty', 'good', 'overall'],
#  ['child', 'loves'],
#  ['small', 'good'],
#  ['cannot', 'go', 'wrong'],
#  ['yummy', 'small'],
#  ['berry', 'wary'],
#  ['highly', 'recomended'],
#  ['berry', 'snack', 'bars'],
#  ['great', 'snack'],
#  ['great', 'bars', 'gluten', 'free', 'diets'],
#  ['absolutely', 'vile'],
#  ['fantastic', 'coffee', 'best', 'ever'],
#  ['strictly', 'best'],
#  ['best', 'coffee'],
#  ['beautiful', 'presentation', 'pretty', 'good', 'tea'],
#  ['break', 'easily'],
#  ['wonderful', 'tea'],
#  ['cannot', 'take', 'smell'],
#  ['twins', 'love', 'one', 'subscription', 'price', 'fair'],
#  ['dessert', 'nutritional', 'enough'],
#  ['repeated', 'deliveries', 'broken', 'jars', 'great', 'product', 'though'],
#  ['good', 'flavor', 'runny', 'though'],
#  ['12', 'protein', '50', 'vitamin'],
#  ['baby', 'lilly', 'says', '2', 'thumbs'],
#  ['earth', 'best', 'rice', 'lentil', 'dinner'],
#  ['plastic', 'food'],
#  ['baby', 'favorite', '2nd', 'stage', 'food', 'far', 'great', 'constipation'],
#  ['sons', 'favorite', 'dinner'],
#  ['issues'],
#  ['thin'],
#  ['great', 'place', 'start'],
#  ['good', 'best', 'flavor'],
#  ['favorite'],
#  ['runny', 'odd', 'tasting'],
#  ['runny'],
#  ['great', 'taste', 'picky', 'baby', 'thin', 'compared', 'others'],
#  ['great', 'stuff'],
#  ['son', 'loves'],
#  ['love'],
#  ['found', 'shredded', 'plastic', 'baby', 'food'],
#  ['son', 'loves'],
#  ['meh', 'daughter', 'eats', 'everything', 'else', 'thing'],
#  ['yummy', 'earth', 'best', 'flavors'],
#  ['son', '2nd', 'favorite', 'dish'],
#  ['toss', '9', '12', 'jars'],
#  ['one', 'favorites'],
#  ['baby', 'likes'],
#  ['baby', 'favorite', 'dinner'],
#  ['daughter', 'favorite', 'jarred', 'food'],
#  ['yum'],
#  ['jarred', 'baby', 'food', 'son', 'ate'],
#  ['little', 'watery', '2nd', 'foods', 'eb'],
#  ['50', 'calories', 'yumminess'],
#  ['organic', 'tasty'],
#  ['one', 'son', 'favorites'],
#  ['great'],
#  ['make', 'best', 'baby', 'food'],
#  ['favorite'],
#  ['geat', 'product'],
#  ['garbanzo', 'beans', 'give', 'horrible', 'gas'],
#  ['baby', 'like'],
#  ['baby', 'favorite', 'dinner'],
#  ['baby', 'loves', 'plastic'],
#  ['baby', 'likes', 'one'],
#  ['organic', 'tasty'],
#  ['baby', 'liked'],
#  ['moms', 'dads', 'beware', 'plastic', 'food'],
#  ['allday', 'energy'],
#  ['best'],
#  ['tasty', 'fruit'],
#  ['beautiful', 'fresh', 'came', 'easrly', 'v', 'yey'],
#  ['fresh', 'fruit', 'dark', 'chocolate'],
#  ['sassafras', 'tea', 'bags'],
#  ['sassafrass', 'tea'],
#  ['good', 'tasten', 'tea'],
#  ['hard', 'find', 'tea'],
#  ['better', 'taste', 'expected'],
#  ['lovely'],
#  ['k'],
#  ['great', 'product'],
#  ['sass', 'tea'],
#  ['awful', 'taste'],
#  ['good'],
#  ['great', 'product'],
#  ['great', 'paste', 'way', 'overpriced', 'like', '3x'],
#  ['easy', 'use'],
#  ['omg', 'buy'],
#  ['wonderful', 'gravy'],
#  ['yeeeee', 'hawww'],
#  ['best', 'white', 'gravy'],
#  ['pioneer', 'gravy', 'great'],
#  ['eco', 'sugar'],
#  ['expensive', 'online'],
#  ['convenient', 'far', 'better', 'instant', 'coffee'],
#  ['pot', 'fresh', 'coffee'],
#  ['simple', 'convenient'],
#  ['brews', 'excellent', 'cup', 'coffee', 'quickly', 'easily'],
#  ['convenient'],
#  ['great', 'taste'],
#  ['delish'],
#  ['new', 'rooibos', 'tea'],
#  ['tasted', 'better', 'loose', 'leaf', 'rooibos'],
#  ['best', 'matcha', 'quality', 'price'],
#  ['best'],
#  ['moore', 'marinade', 'gluten', 'low', 'sodium', 'msg', 'free'],
#  ['great', 'tasting', 'diet', 'tea', 'natural', 'ingredients'],
#  ['awesome', 'sauce'],
#  ['love', 'hot', 'sauce'],
#  ['great', 'hot', 'sauce'],
#  ['love', 'stuff'],
#  ['best', 'sauce', 'around'],
#  ['tasty', 'hot', 'sauce'],
#  ['best', 'around', 'hot', 'sauce'],
#  ['best', 'hot', 'sauce', 'around'],
#  ['hot', 'flavorful'],
#  ['great', 'hot', 'sauce', 'people', 'run'],
#  ['sauce', 'shiznit'],
#  ['hot'],
#  ['hot', 'habanero'],
#  ...]

# %%
def process_data_index(datas,vocab2id) :
    data_indexs = []
    for words in datas:
        line_index = [vocab2id[w] if w in vocab2id else vocab2id["<UNK>"] for w in words]
        data_indexs.append(line_index)
    return data_indexs

# %%
target_data_ids = process_data_index(target_data, vocab2id)
source_data_ids = process_data_index(source_data, vocab2id)

# %%
print("vocab test: ", [id2vocab[i] for i in range(11)])
print("source test: ", source_data[2])
print("source index: ", source_data_ids[2])
print("target test: ", target_data[2])
print("target index: ", target_data_ids[2])
# Out:
# vocab test:  ['<PAD>', '<UNK>', '<GO>', '<EOS>', 'good', 'quality', 'dog', 'food', 'advertised', 'delight', 'says']
# source test:  ['confection', 'around', 'centuries', 'light', 'pillowy', 'citrus', 'gelatin', 'nuts', 'case', 'filberts', 'cut', 'tiny', 'squares', 'liberally', 'coated', 'powdered', 'sugar', 'tiny', 'mouthful', 'heaven', 'chewy', 'flavorful', 'highly', 'recommend', 'yummy', 'treat', 'familiar', 'story', 'c', 'lewis', 'lion', 'witch', 'wardrobe', 'treat', 'seduces', 'edmund', 'selling', 'brother', 'sisters', 'witch']
# source index:  [3054, 532, 3055, 282, 3056, 3057, 3058, 91, 318, 3059, 3027, 1200, 3060, 3061, 3062, 2102, 384, 1200, 1723, 904, 1967, 952, 498, 1832, 38, 484, 3063, 3064, 674, 3065, 3066, 3067, 3068, 484, 3069, 3070, 3071, 3072, 3073, 3067]
# target test:  ['delight', 'says']
# target index:  [9, 10]

# %%
def process_input_data(source_data_ids, target_indexs, vocab2id):
    source_inputs = []
    decoder_inputs, decoder_outputs = [], []
    for source, target in zip(source_data_ids, target_indexs):
        source_inputs.append([vocab2id["<GO>"]] + source + [vocab2id["<EOS>"]])
        decoder_inputs.append([vocab2id["<GO>"]] + target)
        decoder_outputs.append(target + [vocab2id["<EOS>"]])
    return source_inputs, decoder_inputs, decoder_outputs

source_input_ids, target_input_ids, target_output_ids = process_input_data(source_data_ids, target_data_ids, vocab2id)

# %%
print("encoder inputs: ", source_input_ids[1])
print("decoder inputs: ", target_input_ids[:2])
print("decoder outputs: ", target_output_ids[:2])
# Out:
# encoder inputs:  [2, 50, 287, 3049, 3050, 650, 94, 94, 1248, 349, 222, 641, 411, 3051, 1212, 3052, 3053, 50, 3050, 3]
# decoder inputs:  [[2, 4, 5, 6, 7], [2, 8]]
# decoder outputs:  [[4, 5, 6, 7, 3], [8, 3]]

# %%
maxlen = 10
source_input_ids = keras.preprocessing.sequence.pad_sequences(source_input_ids, padding='post', maxlen=20)
target_input_ids = keras.preprocessing.sequence.pad_sequences(target_input_ids, padding='post',  maxlen=maxlen)
target_output_ids = keras.preprocessing.sequence.pad_sequences(target_output_ids, padding='post',  maxlen=maxlen)
print(source_input_ids[:4])
print(target_input_ids[:10])
print(target_output_ids[:10])
# Out:
# [[   6    7 2072  778    4    5   50  213   87 3046 1734  836 1073   30
#   3047 2973 3048   50   30    3]
#  [   2   50  287 3049 3050  650   94   94 1248  349  222  641  411 3051
#   1212 3052 3053   50 3050    3]
#  [ 952  498 1832   38  484 3063 3064  674 3065 3066 3067 3068  484 3069
#   3070 3071 3072 3073 3067    3]
#  [   2  319  808 1263 3074  705  778  794 2101 3075 1316 1383 1338    4
#    743 1176  960   55 1294    3]]
# [[ 2  4  5  6  7  0  0  0  0  0]
#  [ 2  8  0  0  0  0  0  0  0  0]
#  [ 2  9 10  0  0  0  0  0  0  0]
#  [ 2 11 12  0  0  0  0  0  0  0]
#  [ 2 13 14  0  0  0  0  0  0  0]
#  [ 2 15 14  0  0  0  0  0  0  0]
#  [ 2 13  4 16 17  0  0  0  0  0]
#  [ 2 18 19 14  0  0  0  0  0  0]
#  [ 2 20 21  0  0  0  0  0  0  0]
#  [ 2 22  6  7  0  0  0  0  0  0]]
# [[ 4  5  6  7  3  0  0  0  0  0]
#  [ 8  3  0  0  0  0  0  0  0  0]
#  [ 9 10  3  0  0  0  0  0  0  0]
#  [11 12  3  0  0  0  0  0  0  0]
#  [13 14  3  0  0  0  0  0  0  0]
#  [15 14  3  0  0  0  0  0  0  0]
#  [13  4 16 17  3  0  0  0  0  0]
#  [18 19 14  3  0  0  0  0  0  0]
#  [20 21  3  0  0  0  0  0  0  0]
#  [22  6  7  3  0  0  0  0  0  0]]

# %%
class Encoder(keras.Model):
    def __init__(self, vocab_size, embedding_dim, hidden_units):
        super(Encoder, self).__init__()
        # Embedding Layer
        self.embedding = Embedding(vocab_size, embedding_dim, mask_zero=True)
        # Encode LSTM Layer
        self.encoder_lstm = LSTM(hidden_units, return_sequences=True, return_state=True, name="encode_lstm")
        
    def call(self, inputs):
        encoder_embed = self.embedding(inputs)
        encoder_outputs, state_h, state_c = self.encoder_lstm(encoder_embed)
        return encoder_outputs, state_h, state_c

# %%
class Decoder(keras.Model):
    def __init__(self, vocab_size, embedding_dim, hidden_units):
        super(Decoder, self).__init__()
        # Embedding Layer
        self.embedding = Embedding(vocab_size, embedding_dim, mask_zero=True)
        # Decode LSTM Layer
        self.decoder_lstm = LSTM(hidden_units, return_sequences=True, return_state=True, name="decode_lstm")
        # Attention Layer
        self.attention = Attention()
    
    def call(self, enc_outputs, dec_inputs, states_inputs):
        decoder_embed = self.embedding(dec_inputs)
        dec_outputs, dec_state_h, dec_state_c = self.decoder_lstm(decoder_embed, initial_state=states_inputs)
        attention_output = self.attention([dec_outputs, enc_outputs])
        
        return attention_output, dec_state_h, dec_state_c

# %%
def Seq2Seq(maxlen, embedding_dim, hidden_units, vocab_size):
    """
    seq2seq model
    """
    # Input Layer
    encoder_inputs = Input(shape=(maxlen,), name="encode_input")
    decoder_inputs = Input(shape=(None,), name="decode_input")
    # Encoder Layer
    encoder = Encoder(vocab_size, embedding_dim, hidden_units)
    enc_outputs, enc_state_h, enc_state_c = encoder(encoder_inputs)
    dec_states_inputs = [enc_state_h, enc_state_c]
    # Decoder Layer
    decoder = Decoder(vocab_size, embedding_dim, hidden_units)
    attention_output, dec_state_h, dec_state_c = decoder(enc_outputs, decoder_inputs, dec_states_inputs)
    # Dense Layer
    dense_outputs = Dense(vocab_size, activation='softmax', name="dense")(attention_output)
    # seq2seq model
    model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=dense_outputs)
    
    return model

# %%
K.clear_session()

maxlen = 10
embedding_dim = 50
hidden_units = 128
vocab_size = len(vocab2id)

model = Seq2Seq(maxlen, embedding_dim, hidden_units, vocab_size)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encode_input (InputLayer)       [(None, 10)]         0
# __________________________________________________________________________________________________
# encoder (Encoder)               ((None, 10, 128), (N 810898      encode_input[0][0]
# __________________________________________________________________________________________________
# decode_input (InputLayer)       [(None, None)]       0
# __________________________________________________________________________________________________
# decoder (Decoder)               ((None, None, 128),  810898      encoder[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 14385)  1855665     decoder[0][0]
# ==================================================================================================
# Total params: 3,477,461
# Trainable params: 3,477,461
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 49
batch_size = 32
val_rate = 0.2

loss_fn = keras.losses.SparseCategoricalCrossentropy()
model.compile(loss=loss_fn, optimizer='adam')
model.fit([source_input_ids, target_input_ids], target_output_ids, 
          batch_size=batch_size, epochs=epochs, validation_split=val_rate)
# Out:
# Epoch 1/49
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input Tensor("encode_input:0", shape=(None, 10), dtype=float32), but it was called on an input with incompatible shape (32, 20).
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input Tensor("encode_input:0", shape=(None, 10), dtype=float32), but it was called on an input with incompatible shape (32, 20).
# 125/125 [==============================] - ETA: 0s - loss: 8.4247WARNING:tensorflow:Model was constructed with shape (None, 10) for input Tensor("encode_input:0", shape=(None, 10), dtype=float32), but it was called on an input with incompatible shape (None, 20).
# 125/125 [==============================] - 41s 327ms/step - loss: 8.4247 - val_loss: 8.1334
# Epoch 2/49
# 125/125 [==============================] - 39s 308ms/step - loss: 7.8362 - val_loss: 8.0184
# Epoch 3/49
#   2/125 [..............................] - ETA: 18s - loss: 7.7018

# %%
model.save_weights("data/seq2seq_attention_weights.h5")

# %%
def encoder_infer(model):
    encoder_model = Model(inputs=model.get_layer('encoder').input, 
                        outputs=model.get_layer('encoder').output)
    return encoder_model

encoder_model = encoder_infer(model)
print(encoder_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encode_input (InputLayer)    [(None, 10)]              0
# _________________________________________________________________
# encoder (Encoder)            ((None, 10, 128), (None,  403998
# =================================================================
# Total params: 403,998
# Trainable params: 403,998
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def decoder_infer(model, encoder_model):
    encoder_output = encoder_model.get_layer('encoder').output[0]
    maxlen, hidden_units = encoder_output.shape[1:]
    
    dec_input = model.get_layer('decode_input').input
    enc_output = Input(shape=(maxlen, hidden_units), name='enc_output')
    dec_input_state_h = Input(shape=(hidden_units,), name='input_state_h')
    dec_input_state_c = Input(shape=(hidden_units,), name='input_state_c')
    dec_input_states = [dec_input_state_h, dec_input_state_c]

    decoder = model.get_layer('decoder')
    dec_outputs, out_state_h, out_state_c = decoder(enc_output, dec_input, dec_input_states)
    dec_output_states = [out_state_h, out_state_c]

    decoder_dense = model.get_layer('dense')
    dense_output = decoder_dense(dec_outputs)

    decoder_model = Model(inputs=[enc_output, dec_input, dec_input_states], 
                          outputs=[dense_output]+dec_output_states)
    return decoder_model

decoder_model = decoder_infer(model, encoder_model)
print(decoder_model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# enc_output (InputLayer)         [(None, 10, 128)]    0
# __________________________________________________________________________________________________
# decode_input (InputLayer)       [(None, None)]       0
# __________________________________________________________________________________________________
# input_state_h (InputLayer)      [(None, 128)]        0
# __________________________________________________________________________________________________
# input_state_c (InputLayer)      [(None, 128)]        0
# __________________________________________________________________________________________________
# decoder (Decoder)               ((None, None, 128),  403998      enc_output[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 6247)   805863      decoder[1][0]
# ==================================================================================================
# Total params: 1,209,861
# Trainable params: 1,209,861
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
import numpy as np

maxlen = 10

def infer_predict(input_text, encoder_model, decoder_model):
    text_words = input_text.split()[:maxlen]
    input_id = [vocab2id[w] if w in vocab2id else vocab2id["<UNK>"] for w in text_words]
    input_id = [vocab2id["<GO>"]] + input_id + [vocab2id["<EOS>"]]
    if len(input_id) < maxlen:
        input_id = input_id + [vocab2id["<PAD>"]] * (maxlen-len(input_id))

    input_source = np.array([input_id])
    input_target = np.array([vocab2id["<GO>"]])
    
    # 编码器encoder预测输出
    enc_outputs, enc_state_h, enc_state_c = encoder_model.predict([input_source])
    dec_inputs = input_target
    dec_states_inputs = [enc_state_h, enc_state_c]

    result_id = []
    result_text = []
    for i in range(maxlen):
        # 解码器decoder预测输出
        dense_outputs, dec_state_h, dec_state_c = decoder_model.predict([enc_outputs, dec_inputs]+dec_states_inputs)
        pred_id = np.argmax(dense_outputs[0][0])
        result_id.append(pred_id)
        result_text.append(id2vocab[pred_id])
        if id2vocab[pred_id] == "<EOS>":
            break
        dec_inputs = np.array([[pred_id]])
        dec_states_inputs = [dec_state_h, dec_state_c]
    return result_id, result_text

# %%
input_text = "bought several vitali "
result_id, result_text = infer_predict(input_text, encoder_model, decoder_model)

print("Input: ", input_text)
print("Output: ", result_text, result_id)
# Out:
# Input:  bought several vitali
# Output:  ['<EOS>'] [3]
