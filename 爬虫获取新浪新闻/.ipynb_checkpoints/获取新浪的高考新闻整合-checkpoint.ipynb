# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import sqlite3

# %%
news_dict = {'title':[],'href':[],'time':[],'acticle':[]}
for h in tqdm(range(1,11)):
    r = requests.get('http://edu.sina.com.cn/other/roll.d.html?cat=80459&page={page}&page_size=30'.format(page = h))
    r.encoding = 'utf-8'
    soup = BeautifulSoup(r.text,'html.parser')
    new =soup.find_all('li')
    for i in  range(len(new)):
        href = new[i]('a')[0]['href']
        data = new[i]('span')[0].text.strip('()')
        title = new[i].text
        news_dict['title'].append(title)
        news_dict['href'].append(href)
        news_dict['time'].append(data)
    for i in tqdm(range(0,30)):
        try:
            res = requests.get(news_dict['href'][i])
            res.encoding = 'utf-8'
            soup = BeautifulSoup(res.text,'html.parser')
            new = soup.find('div','article')
            st1=new.text.replace(u'\n\u3000\u3000', u' ').replace(u'\n\n\n\n',u'').replace(u'\n\n',u'')
        except:
            print('地址为{}新闻抓取失败'.format(news_dict['href'][i]))
            st1 = '没有获取数据'
            continue
    
        news_dict['acticle'].append(st1)
# Out:
#  60%|█████████████████████████████████████████████████▊                                 | 6/10 [00:46<00:30,  7.74s/it]
# 地址为https://edu.sina.com.cn/gaokao/2020-02-26/doc-iimxyqvz5881744.shtml新闻抓取失败
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:41<00:00, 10.14s/it]

# %%
df = pd.DataFrame.from_dict(news_dict, orient='index')

# %%
df
# Out:
#                                                        0    \
# title           上海：推迟2020年高校考试招生体育类专业统考(2020年02月26日 10:51)
# href     https://edu.sina.com.cn/gaokao/2020-02-26/doc-...
# time                                     2020年02月26日 10:51
# acticle  \t\t\t\t\twindow.sina_survey_config = {\n    \...
#
#                                                        1    \
# title              陕西：关于近期教育考试招生工作安排的公告(2020年02月26日 10:50)
# href     https://edu.sina.com.cn/gaokao/2020-02-26/doc-...
# time                                     2020年02月26日 10:50
# acticle  \t\t\t\t\twindow.sina_survey_config = {\n    \...
#
#                                                        2    \
# title          下周北京新高考模拟连考4天 居家考试可请家长监考(2020年02月25日 12:27)
# href     https://edu.sina.com.cn/gaokao/2020-02-25/doc-...
# time                                     2020年02月25日 12:27
# acticle  \t\t\t\t\twindow.sina_survey_config = {\n    \...
#
#                                                        3    \
# title          北京101中校长陆云泉：在家“高考”为战疫做贡献(2020年02月25日 12:25)
# href     https://edu.sina.com.cn/gaokao/2020-02-25/doc-...
# time                                     2020年02月25日 12:25
# acticle  \t\t\t\t\twindow.sina_survey_config = {\n    \...
#
#                                                        4    \
# title            北京2020年新高考适应性测试(模拟考)问答(2020年02月25日 12:20)
# href     https://edu.sina.com.cn/gaokao/2020-02-25/doc-...
# time                                     2020年02月25日 12:20
# acticle  \t\t\t\t\twindow.sina_survey_config = {\n    \...
#
#                                                        5    \
# title                 北京：全市新高考“模拟考”推迟一周(2020年02月25日 12:17)
# href     https://edu.sina.com.cn/gaokao/2020-02-25/doc-...
# time                                     2020年02月25日 12:17
# acticle  \t\t\t\t\twindow.sina_survey_config = {\n    \...
#
#                                                        6    \
# title                内蒙古：力保蒙语授课高三师生在线学习(2020年02月25日 12:16)
# href     https://edu.sina.com.cn/gaokao/2020-02-25/doc-...
# time                                     2020年02月25日 12:16
# acticle  \t\t\t\t\twindow.sina_survey_config = {\n    \...
#
#                                                